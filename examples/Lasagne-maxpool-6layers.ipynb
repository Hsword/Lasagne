# %%
import numpy as np
import pickle as pkl
import networkx as nx
import scipy.sparse as sp
import torch
from scipy.sparse import csgraph
import sys
import time
import argparse
import numpy as np
import torch
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from utils import *
from graphConvolution import *
from torch import nn

# %% [markdown]
# ### Load data

# %%
adj, features, labels, idx_train, idx_val, idx_test = load_data(dataset='cora')
# Out:
# [STEP 1]: Upload cora dataset.
# | # of nodes : 2708
# | # of edges : 5278.0
# | # of features : 1433
# | # of clases   : 7
# | # of train set : 140
# | # of val set   : 500
# | # of test set  : 1000

# %%
from torch.autograd import Variable
features, adj, labels = Variable(features), Variable(adj), Variable(labels)
# torch.cuda.manual_seed(72)
features = features.cuda()
adj = adj.cuda()
labels = labels.cuda()
idx_train = idx_train.cuda()
idx_val = idx_val.cuda()
idx_test = idx_test.cuda()

# %% [markdown]
# ### FM-6layers

# %%
class GraphConvolutionFM(Module):
    def __init__(self, in_features, out_features, embedding, bias=True):
        super(GraphConvolutionFM, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.embedding = embedding
        self.weight = Parameter(torch.FloatTensor(in_features, out_features),requires_grad=True)
        self.V = Parameter(torch.randn(out_features, in_features, embedding),requires_grad=True)
        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        self.V.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj,nhid1,nhid2,nhid3,nhid4):
        out_lin = torch.mm(input, self.weight) + self.bias
        # all
        out_1 = torch.matmul(input,self.V).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_2 = torch.matmul(input.pow(2), self.V.pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter1 = 0.5*(out_1 - out_2)
        # x1-xnhid1
        out_3 = torch.matmul(input[:,:nhid1],self.V[:,:nhid1,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_4 = torch.matmul(input[:,:nhid1].pow(2), self.V[:,:nhid1,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter2 = 0.5*(out_3 - out_4)
        # xnhid1-xnhid2
        out_5 = torch.matmul(input[:,nhid1:nhid2],self.V[:,nhid1:nhid2,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_6 = torch.matmul(input[:,nhid1:nhid2].pow(2), self.V[:,nhid1:nhid2,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter3 = 0.5*(out_5 - out_6)
        # xnhid2-xnhid3
        out_7 = torch.matmul(input[:,nhid2:nhid3],self.V[:,nhid2:nhid3,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_8 = torch.matmul(input[:,nhid2:nhid3].pow(2), self.V[:,nhid2:nhid3,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter4 = 0.5*(out_7 - out_8)
        # xnhid3-xnhid4
        out_9 = torch.matmul(input[:,nhid3:nhid4],self.V[:,nhid3:nhid4,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_10 = torch.matmul(input[:,nhid3:nhid4].pow(2), self.V[:,nhid3:nhid4,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter5 = 0.5*(out_9- out_10)
        
        # xnhid4-xnhid5
        out_11 = torch.matmul(input[:,nhid4:],self.V[:,nhid4:,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_12 = torch.matmul(input[:,nhid4:].pow(2), self.V[:,nhid4:,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter6 = 0.5*(out_11- out_12)
        
        out_inter = out_inter1 - out_inter2 - out_inter3- out_inter4- out_inter5-out_inter6
        
        output = out_inter + out_lin
        
        output = torch.spmm(adj, output) 
        return output
    

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

# %%
class GCN(nn.Module):
    def __init__(self, nfeat, nhid1,nhid2, nhid3,nhid4,nhid5,nclass, dropout):
        super(GCN, self).__init__()
        self.nhid1 = nhid1
        self.nhid2 = nhid2
        self.nhid3 = nhid3
        self.nhid4 = nhid4
        self.nhid5 = nhid5
        
        self.gc_1 = GraphConvolution(nfeat, nhid1,bias=True)
        self.gc_2 = GraphConvolution(nfeat, nhid2,bias=True)
        self.gc_3 = GraphConvolution(nfeat, nhid3,bias=True)
        self.gc_4 = GraphConvolution(nfeat, nhid4,bias=True)
        
        self.gc1 = GraphConvolution(nfeat, nhid1,bias=True)
        self.gc1_2 = GraphConvolution(nhid1, nhid2,bias=True)
        self.gc1_3 = GraphConvolution(nhid1, nhid3,bias=True)
        self.gc1_4 = GraphConvolution(nhid1, nhid4,bias=True)
        
        
        self.gc2 = GraphConvolution(nhid1, nhid2,bias=True)
        self.gc2_3 = GraphConvolution(nhid2, nhid3,bias=True)
        self.gc2_4 = GraphConvolution(nhid2, nhid4,bias=True)

        
        self.gc3 = GraphConvolution(nhid2, nhid3,bias=True)
        self.gc3_4 = GraphConvolution(nhid3, nhid4,bias=True)
        
        self.gc4 = GraphConvolution(nhid3, nhid4,bias=True)
        
        self.gc5 = GraphConvolution(nhid4, nhid5,bias=True)
        
        self.gcFM6 = GraphConvolutionFM(nhid5+nhid4+nhid3+nhid2+nhid1, nclass,embedding=5,bias=True)
        
        self.dropout = dropout

    def forward(self, x, adj):
        x_d = F.dropout(x, self.dropout, training=self.training)
        x_df1 = F.dropout(F.relu(self.gc_1(x_d,adj)), self.dropout, training=self.training)
        x_df2 = F.dropout(F.relu(self.gc_2(x_d,adj)), self.dropout, training=self.training)
        x_df3 = F.dropout(F.relu(self.gc_3(x_d,adj)), self.dropout, training=self.training)
        x_df4 = F.dropout(F.relu(self.gc_4(x_d,adj)), self.dropout, training=self.training)

        x1_d = F.dropout(F.relu(self.gc1(x_d, adj)), training=self.training)
        x1_df2 = F.dropout(F.relu(self.gc1_2(x1_d,adj)), self.dropout, training=self.training)
        x1_df3 = F.dropout(F.relu(self.gc1_3(x1_d,adj)), self.dropout, training=self.training)
        x1_df4 = F.dropout(F.relu(self.gc1_4(x1_d,adj)), self.dropout, training=self.training)
        
        combined1 =  torch.cat([x_df1,x1_d],dim=1).view(x.shape[0],2,self.nhid1)
        combined1 = torch.max(combined1,dim=1).values
        combined1 = F.dropout(combined1, self.dropout, training=self.training)
        
        x2_d = F.dropout(F.relu(self.gc2(combined1, adj)), self.dropout, training=self.training)
        x2_df3 = F.dropout(F.relu(self.gc2_3(x2_d,adj)), self.dropout, training=self.training)
        x2_df4 = F.dropout(F.relu(self.gc2_4(x2_d,adj)), self.dropout, training=self.training)

        combined2 =  torch.cat([x_df2,x1_df2,x2_d],dim=1).view(x.shape[0],3,self.nhid2)
        combined2 = torch.max(combined2,dim=1).values
        combined2 = F.dropout(combined2, self.dropout, training=self.training)

        x3_d = F.dropout(F.relu(self.gc3(combined2, adj)), self.dropout, training=self.training)
        x3_df4 = F.dropout(F.relu(self.gc3_4(x3_d,adj)), self.dropout, training=self.training)
        
        combined3 =  torch.cat([x_df3,x1_df3,x2_df3,x3_d],dim=1).view(x.shape[0],4,self.nhid3)
        combined3 = torch.max(combined3,dim=1).values
        combined3 = F.dropout(combined3, self.dropout, training=self.training)
        
        x4_d = F.dropout(F.relu(self.gc4(combined3, adj)), self.dropout, training=self.training)
        
        combined4 =  torch.cat([x_df4,x1_df4,x2_df4,x3_df4,x4_d],dim=1).view(x.shape[0],5,self.nhid4)
        combined4 = torch.max(combined4,dim=1).values
        combined4 = F.dropout(combined4, self.dropout, training=self.training)
        
        
        x5_d = F.dropout(F.relu(self.gc5(combined4, adj)), self.dropout, training=self.training)
        
        combined5 = torch.cat([x1_d, x2_d, x3_d, x4_d, x5_d], dim=1)
        combined5 = F.dropout(combined5, self.dropout, training=self.training)
        
        x6 = self.gcFM6(combined5,adj,self.nhid1,self.nhid2+self.nhid1,self.nhid3+self.nhid2+self.nhid1,self.nhid4+self.nhid3+self.nhid2+self.nhid1) 
        return F.log_softmax(x6, dim=1)

# %%
def train(epoch, model,record):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    output = model(features, adj)
    loss_train = F.cross_entropy(output[idx_train], labels[idx_train]) 
    acc_train = accuracy(output[idx_train], labels[idx_train])
    loss_train.backward()
    optimizer.step()
    model.eval()
    output = model(features, adj)

    loss_val = F.cross_entropy(output[idx_val], labels[idx_val])
    acc_val = accuracy(output[idx_val], labels[idx_val])
    
    loss_test = F.cross_entropy(output[idx_test], labels[idx_test])
    acc_test = accuracy(output[idx_test], labels[idx_test])
    print('Epoch: {:04d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'acc_train: {:.4f}'.format(acc_train.item()),
          'acc_val: {:.4f}'.format(acc_val.item()),
          'acc_test: {:.4f}'.format(acc_test.item()),
          'time: {:.4f}s'.format(time.time() - t))
    record[acc_val.item()] = acc_test.item()

# %%
model = GCN(nfeat=features.shape[1],
                nhid1=32,
                nhid2=32,
                nhid3=32,
                nhid4=32,
                nhid5=32,
                nclass=labels.max().item() + 1,
                dropout=0.8)
model.cuda()
optimizer = optim.Adam(model.parameters(),
                       lr=0.02, weight_decay=5e-4)
t_total = time.time()
record = {}
for epoch in range(400):  
    train(epoch,model,record)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
bit_list = sorted(record.keys())
bit_list.reverse()
for key in bit_list[:10]:
    value = record[key]
    print(key,value)
# Out:
# Epoch: 0001 loss_train: 10.1382 acc_train: 0.1286 acc_val: 0.1320 acc_test: 0.1190 time: 0.4096s
# Epoch: 0002 loss_train: 3.3943 acc_train: 0.1571 acc_val: 0.1620 acc_test: 0.1490 time: 0.0247s
# Epoch: 0003 loss_train: 2.7748 acc_train: 0.1143 acc_val: 0.1540 acc_test: 0.1470 time: 0.0302s
# Epoch: 0004 loss_train: 2.2759 acc_train: 0.1357 acc_val: 0.1260 acc_test: 0.1310 time: 0.0236s
# Epoch: 0005 loss_train: 2.2139 acc_train: 0.1071 acc_val: 0.1420 acc_test: 0.1400 time: 0.0257s
# Epoch: 0006 loss_train: 2.0917 acc_train: 0.1571 acc_val: 0.1580 acc_test: 0.1500 time: 0.0303s
# Epoch: 0007 loss_train: 2.0865 acc_train: 0.1429 acc_val: 0.1740 acc_test: 0.1500 time: 0.0237s
# Epoch: 0008 loss_train: 2.0954 acc_train: 0.1071 acc_val: 0.3160 acc_test: 0.3330 time: 0.0259s
# Epoch: 0009 loss_train: 1.9814 acc_train: 0.1571 acc_val: 0.3100 acc_test: 0.3240 time: 0.0326s
# Epoch: 0010 loss_train: 1.9121 acc_train: 0.1857 acc_val: 0.3080 acc_test: 0.3200 time: 0.0305s
# Epoch: 0011 loss_train: 1.9890 acc_train: 0.1714 acc_val: 0.3080 acc_test: 0.3190 time: 0.0305s
# Epoch: 0012 loss_train: 1.9969 acc_train: 0.1214 acc_val: 0.3080 acc_test: 0.3220 time: 0.0314s
# Epoch: 0013 loss_train: 1.9561 acc_train: 0.1857 acc_val: 0.3180 acc_test: 0.3440 time: 0.0295s
# Epoch: 0014 loss_train: 1.9931 acc_train: 0.1429 acc_val: 0.3340 acc_test: 0.3650 time: 0.0307s
# Epoch: 0015 loss_train: 1.9487 acc_train: 0.1286 acc_val: 0.3420 acc_test: 0.3890 time: 0.0299s
# Epoch: 0016 loss_train: 1.9039 acc_train: 0.2571 acc_val: 0.3220 acc_test: 0.3800 time: 0.0303s
# Epoch: 0017 loss_train: 1.9423 acc_train: 0.2071 acc_val: 0.2240 acc_test: 0.2860 time: 0.0309s
# Epoch: 0018 loss_train: 1.9762 acc_train: 0.1714 acc_val: 0.1300 acc_test: 0.1740 time: 0.0306s
# Epoch: 0019 loss_train: 1.9566 acc_train: 0.2071 acc_val: 0.0960 acc_test: 0.1230 time: 0.0357s
# Epoch: 0020 loss_train: 1.9779 acc_train: 0.2143 acc_val: 0.0960 acc_test: 0.1140 time: 0.0285s
# Epoch: 0021 loss_train: 1.9620 acc_train: 0.2714 acc_val: 0.0980 acc_test: 0.1190 time: 0.0305s
# Epoch: 0022 loss_train: 1.9350 acc_train: 0.2214 acc_val: 0.1200 acc_test: 0.1510 time: 0.0304s
# Epoch: 0023 loss_train: 1.9557 acc_train: 0.2071 acc_val: 0.1560 acc_test: 0.1820 time: 0.0297s
# Epoch: 0024 loss_train: 1.9245 acc_train: 0.2071 acc_val: 0.1800 acc_test: 0.1960 time: 0.0307s
# Epoch: 0025 loss_train: 1.9424 acc_train: 0.2786 acc_val: 0.1920 acc_test: 0.2060 time: 0.0304s
# Epoch: 0026 loss_train: 1.9109 acc_train: 0.2357 acc_val: 0.1940 acc_test: 0.2110 time: 0.0357s
# Epoch: 0027 loss_train: 1.9289 acc_train: 0.2357 acc_val: 0.1880 acc_test: 0.2150 time: 0.0286s
# Epoch: 0028 loss_train: 1.8743 acc_train: 0.2857 acc_val: 0.2020 acc_test: 0.2240 time: 0.0302s
# Epoch: 0029 loss_train: 1.8518 acc_train: 0.2857 acc_val: 0.2160 acc_test: 0.2390 time: 0.0261s
# Epoch: 0030 loss_train: 1.8903 acc_train: 0.2214 acc_val: 0.2560 acc_test: 0.2540 time: 0.0318s
# Epoch: 0031 loss_train: 1.8760 acc_train: 0.2714 acc_val: 0.2760 acc_test: 0.2890 time: 0.0318s
# Epoch: 0032 loss_train: 1.8604 acc_train: 0.3071 acc_val: 0.3220 acc_test: 0.3310 time: 0.0370s
# Epoch: 0033 loss_train: 1.8620 acc_train: 0.2643 acc_val: 0.3480 acc_test: 0.3540 time: 0.0307s
# Epoch: 0034 loss_train: 1.8204 acc_train: 0.2857 acc_val: 0.3660 acc_test: 0.3780 time: 0.0322s
# Epoch: 0035 loss_train: 1.8413 acc_train: 0.2929 acc_val: 0.3920 acc_test: 0.4000 time: 0.0372s
# Epoch: 0036 loss_train: 1.8617 acc_train: 0.2786 acc_val: 0.4200 acc_test: 0.4540 time: 0.0311s
# Epoch: 0037 loss_train: 1.8365 acc_train: 0.3000 acc_val: 0.5020 acc_test: 0.5260 time: 0.0295s
# Epoch: 0038 loss_train: 1.7968 acc_train: 0.3643 acc_val: 0.5560 acc_test: 0.5970 time: 0.0290s
# Epoch: 0039 loss_train: 1.7962 acc_train: 0.3786 acc_val: 0.6200 acc_test: 0.6690 time: 0.0366s
# Epoch: 0040 loss_train: 1.8318 acc_train: 0.2929 acc_val: 0.6480 acc_test: 0.6940 time: 0.0304s
# Epoch: 0041 loss_train: 1.8355 acc_train: 0.3357 acc_val: 0.6820 acc_test: 0.7150 time: 0.0292s
# Epoch: 0042 loss_train: 1.8291 acc_train: 0.3643 acc_val: 0.6860 acc_test: 0.7190 time: 0.0346s
# Epoch: 0043 loss_train: 1.7496 acc_train: 0.3714 acc_val: 0.6940 acc_test: 0.7180 time: 0.0380s
# Epoch: 0044 loss_train: 1.7852 acc_train: 0.3000 acc_val: 0.6840 acc_test: 0.7130 time: 0.0369s
# Epoch: 0045 loss_train: 1.7505 acc_train: 0.3857 acc_val: 0.6760 acc_test: 0.7070 time: 0.0305s
# Epoch: 0046 loss_train: 1.7751 acc_train: 0.3286 acc_val: 0.6640 acc_test: 0.7030 time: 0.0282s
# Epoch: 0047 loss_train: 1.7704 acc_train: 0.3429 acc_val: 0.6620 acc_test: 0.6980 time: 0.0307s
# Epoch: 0048 loss_train: 1.7310 acc_train: 0.3929 acc_val: 0.6680 acc_test: 0.7030 time: 0.0291s
# Epoch: 0049 loss_train: 1.7753 acc_train: 0.3357 acc_val: 0.6580 acc_test: 0.6910 time: 0.0307s
# Epoch: 0050 loss_train: 1.6953 acc_train: 0.4500 acc_val: 0.6200 acc_test: 0.6460 time: 0.0341s
# Epoch: 0051 loss_train: 1.6993 acc_train: 0.3786 acc_val: 0.6100 acc_test: 0.6240 time: 0.0351s
# Epoch: 0052 loss_train: 1.6226 acc_train: 0.4786 acc_val: 0.6180 acc_test: 0.6280 time: 0.0305s
# Epoch: 0053 loss_train: 1.7313 acc_train: 0.4000 acc_val: 0.6140 acc_test: 0.6320 time: 0.0295s
# Epoch: 0054 loss_train: 1.7172 acc_train: 0.4143 acc_val: 0.6240 acc_test: 0.6320 time: 0.0294s
# Epoch: 0055 loss_train: 1.7245 acc_train: 0.3857 acc_val: 0.6220 acc_test: 0.6360 time: 0.0257s
# Epoch: 0056 loss_train: 1.6818 acc_train: 0.4143 acc_val: 0.6240 acc_test: 0.6410 time: 0.0318s
# Epoch: 0057 loss_train: 1.5774 acc_train: 0.5000 acc_val: 0.6360 acc_test: 0.6440 time: 0.0314s
# Epoch: 0058 loss_train: 1.6967 acc_train: 0.4143 acc_val: 0.6420 acc_test: 0.6610 time: 0.0339s
# Epoch: 0059 loss_train: 1.6054 acc_train: 0.4571 acc_val: 0.6360 acc_test: 0.6590 time: 0.0369s
# Epoch: 0060 loss_train: 1.6304 acc_train: 0.4071 acc_val: 0.6360 acc_test: 0.6570 time: 0.0306s
# Epoch: 0061 loss_train: 1.6624 acc_train: 0.4214 acc_val: 0.6420 acc_test: 0.6590 time: 0.0292s
# Epoch: 0062 loss_train: 1.5780 acc_train: 0.4714 acc_val: 0.6520 acc_test: 0.6630 time: 0.0306s
# Epoch: 0063 loss_train: 1.5634 acc_train: 0.5357 acc_val: 0.6580 acc_test: 0.6800 time: 0.0334s
# Epoch: 0064 loss_train: 1.5663 acc_train: 0.4786 acc_val: 0.6860 acc_test: 0.6950 time: 0.0340s
# Epoch: 0065 loss_train: 1.4768 acc_train: 0.5429 acc_val: 0.7060 acc_test: 0.7180 time: 0.0327s
# Epoch: 0066 loss_train: 1.5575 acc_train: 0.4929 acc_val: 0.7200 acc_test: 0.7370 time: 0.0297s
# Epoch: 0067 loss_train: 1.5602 acc_train: 0.4286 acc_val: 0.7360 acc_test: 0.7570 time: 0.0299s
# Epoch: 0068 loss_train: 1.5611 acc_train: 0.4429 acc_val: 0.7560 acc_test: 0.7730 time: 0.0305s
# Epoch: 0069 loss_train: 1.4581 acc_train: 0.4929 acc_val: 0.7720 acc_test: 0.7770 time: 0.0357s
# Epoch: 0070 loss_train: 1.4834 acc_train: 0.5143 acc_val: 0.7880 acc_test: 0.7840 time: 0.0307s
# Epoch: 0071 loss_train: 1.4827 acc_train: 0.4786 acc_val: 0.7940 acc_test: 0.7920 time: 0.0274s
# Epoch: 0072 loss_train: 1.5189 acc_train: 0.5286 acc_val: 0.7880 acc_test: 0.7920 time: 0.0348s
# Epoch: 0073 loss_train: 1.4617 acc_train: 0.5357 acc_val: 0.7900 acc_test: 0.7920 time: 0.0313s
# Epoch: 0074 loss_train: 1.4457 acc_train: 0.4929 acc_val: 0.7860 acc_test: 0.7860 time: 0.0301s
# Epoch: 0075 loss_train: 1.4484 acc_train: 0.5143 acc_val: 0.7760 acc_test: 0.7830 time: 0.0297s
# Epoch: 0076 loss_train: 1.4381 acc_train: 0.4857 acc_val: 0.7520 acc_test: 0.7770 time: 0.0405s
# Epoch: 0077 loss_train: 1.4694 acc_train: 0.5357 acc_val: 0.7400 acc_test: 0.7710 time: 0.0270s
# Epoch: 0078 loss_train: 1.4261 acc_train: 0.5571 acc_val: 0.7160 acc_test: 0.7550 time: 0.0321s
# Epoch: 0079 loss_train: 1.4500 acc_train: 0.4857 acc_val: 0.7020 acc_test: 0.7330 time: 0.0323s
# Epoch: 0080 loss_train: 1.3902 acc_train: 0.5214 acc_val: 0.6920 acc_test: 0.7240 time: 0.0301s
# Epoch: 0081 loss_train: 1.4063 acc_train: 0.4786 acc_val: 0.7020 acc_test: 0.7250 time: 0.0288s
# Epoch: 0082 loss_train: 1.3360 acc_train: 0.5857 acc_val: 0.7060 acc_test: 0.7340 time: 0.0407s
# Epoch: 0083 loss_train: 1.3612 acc_train: 0.5643 acc_val: 0.7120 acc_test: 0.7390 time: 0.0390s
# Epoch: 0084 loss_train: 1.4367 acc_train: 0.5143 acc_val: 0.7340 acc_test: 0.7500 time: 0.0305s
# Epoch: 0085 loss_train: 1.3451 acc_train: 0.5857 acc_val: 0.7480 acc_test: 0.7650 time: 0.0269s
# Epoch: 0086 loss_train: 1.3114 acc_train: 0.5357 acc_val: 0.7560 acc_test: 0.7750 time: 0.0318s
# Epoch: 0087 loss_train: 1.3230 acc_train: 0.5643 acc_val: 0.7620 acc_test: 0.7810 time: 0.0257s
# Epoch: 0088 loss_train: 1.3364 acc_train: 0.5500 acc_val: 0.7640 acc_test: 0.7850 time: 0.0341s
# Epoch: 0089 loss_train: 1.2710 acc_train: 0.5571 acc_val: 0.7740 acc_test: 0.7940 time: 0.0307s
# Epoch: 0090 loss_train: 1.2557 acc_train: 0.6143 acc_val: 0.7760 acc_test: 0.8000 time: 0.0309s
# Epoch: 0091 loss_train: 1.2630 acc_train: 0.5500 acc_val: 0.7740 acc_test: 0.7970 time: 0.0267s
# Epoch: 0092 loss_train: 1.2676 acc_train: 0.5429 acc_val: 0.7640 acc_test: 0.7910 time: 0.0318s
# Epoch: 0093 loss_train: 1.2937 acc_train: 0.5786 acc_val: 0.7540 acc_test: 0.7840 time: 0.0257s
# Epoch: 0094 loss_train: 1.2805 acc_train: 0.5857 acc_val: 0.7420 acc_test: 0.7720 time: 0.0329s
# Epoch: 0095 loss_train: 1.2516 acc_train: 0.5929 acc_val: 0.7180 acc_test: 0.7520 time: 0.0327s
# Epoch: 0096 loss_train: 1.2579 acc_train: 0.6429 acc_val: 0.7080 acc_test: 0.7420 time: 0.0258s
# Epoch: 0097 loss_train: 1.2329 acc_train: 0.5857 acc_val: 0.7000 acc_test: 0.7400 time: 0.0317s
# Epoch: 0098 loss_train: 1.1861 acc_train: 0.6143 acc_val: 0.7020 acc_test: 0.7400 time: 0.0308s
# Epoch: 0099 loss_train: 1.2017 acc_train: 0.6214 acc_val: 0.7200 acc_test: 0.7470 time: 0.0295s
# Epoch: 0100 loss_train: 1.2102 acc_train: 0.6286 acc_val: 0.7320 acc_test: 0.7570 time: 0.0304s
# Epoch: 0101 loss_train: 1.2685 acc_train: 0.5857 acc_val: 0.7480 acc_test: 0.7700 time: 0.0305s
# Epoch: 0102 loss_train: 1.3004 acc_train: 0.5643 acc_val: 0.7620 acc_test: 0.7840 time: 0.0288s
# Epoch: 0103 loss_train: 1.2182 acc_train: 0.5857 acc_val: 0.7640 acc_test: 0.7880 time: 0.0325s
# Epoch: 0104 loss_train: 1.3279 acc_train: 0.5643 acc_val: 0.7580 acc_test: 0.7800 time: 0.0305s
# Epoch: 0105 loss_train: 1.2859 acc_train: 0.5929 acc_val: 0.7540 acc_test: 0.7740 time: 0.0294s
# Epoch: 0106 loss_train: 1.2328 acc_train: 0.6357 acc_val: 0.7400 acc_test: 0.7700 time: 0.0303s
# Epoch: 0107 loss_train: 1.1835 acc_train: 0.5286 acc_val: 0.7420 acc_test: 0.7680 time: 0.0256s
# Epoch: 0108 loss_train: 1.2285 acc_train: 0.5929 acc_val: 0.7440 acc_test: 0.7730 time: 0.0316s
# Epoch: 0109 loss_train: 1.2146 acc_train: 0.5857 acc_val: 0.7520 acc_test: 0.7750 time: 0.0306s
# Epoch: 0110 loss_train: 1.2000 acc_train: 0.5929 acc_val: 0.7540 acc_test: 0.7790 time: 0.0292s
# Epoch: 0111 loss_train: 1.0988 acc_train: 0.6357 acc_val: 0.7580 acc_test: 0.7830 time: 0.0323s
# Epoch: 0112 loss_train: 1.3099 acc_train: 0.5286 acc_val: 0.7660 acc_test: 0.7860 time: 0.0305s
# Epoch: 0113 loss_train: 1.1630 acc_train: 0.6429 acc_val: 0.7660 acc_test: 0.7890 time: 0.0296s
# Epoch: 0114 loss_train: 1.2254 acc_train: 0.6143 acc_val: 0.7680 acc_test: 0.7870 time: 0.0302s
# Epoch: 0115 loss_train: 1.1111 acc_train: 0.6643 acc_val: 0.7720 acc_test: 0.7870 time: 0.0276s
# Epoch: 0116 loss_train: 1.1320 acc_train: 0.6500 acc_val: 0.7800 acc_test: 0.7880 time: 0.0287s
# Epoch: 0117 loss_train: 1.1498 acc_train: 0.6214 acc_val: 0.7840 acc_test: 0.7970 time: 0.0257s
# Epoch: 0118 loss_train: 1.1582 acc_train: 0.6571 acc_val: 0.7820 acc_test: 0.8000 time: 0.0318s
# Epoch: 0119 loss_train: 1.1506 acc_train: 0.5929 acc_val: 0.7800 acc_test: 0.7990 time: 0.0305s
# Epoch: 0120 loss_train: 1.1382 acc_train: 0.6000 acc_val: 0.7800 acc_test: 0.8020 time: 0.0290s
# Epoch: 0121 loss_train: 1.1980 acc_train: 0.6143 acc_val: 0.7760 acc_test: 0.8030 time: 0.0325s
# Epoch: 0122 loss_train: 1.0958 acc_train: 0.6429 acc_val: 0.7760 acc_test: 0.8020 time: 0.0306s
# Epoch: 0123 loss_train: 1.2863 acc_train: 0.6214 acc_val: 0.7800 acc_test: 0.8050 time: 0.0293s
# Epoch: 0124 loss_train: 1.2014 acc_train: 0.6286 acc_val: 0.7840 acc_test: 0.8070 time: 0.0321s
# Epoch: 0125 loss_train: 1.2216 acc_train: 0.5929 acc_val: 0.7740 acc_test: 0.8010 time: 0.0259s
# Epoch: 0126 loss_train: 1.1631 acc_train: 0.6214 acc_val: 0.7780 acc_test: 0.7990 time: 0.0334s
# Epoch: 0127 loss_train: 1.1404 acc_train: 0.6286 acc_val: 0.7680 acc_test: 0.8020 time: 0.0308s
# Epoch: 0128 loss_train: 1.1432 acc_train: 0.6357 acc_val: 0.7620 acc_test: 0.7940 time: 0.0293s
# Epoch: 0129 loss_train: 1.1319 acc_train: 0.6429 acc_val: 0.7540 acc_test: 0.7860 time: 0.0324s
# Epoch: 0130 loss_train: 1.2188 acc_train: 0.5714 acc_val: 0.7380 acc_test: 0.7680 time: 0.0258s
# Epoch: 0131 loss_train: 1.0845 acc_train: 0.6786 acc_val: 0.7420 acc_test: 0.7680 time: 0.0313s
# Epoch: 0132 loss_train: 1.0937 acc_train: 0.6500 acc_val: 0.7480 acc_test: 0.7680 time: 0.0261s
# Epoch: 0133 loss_train: 1.1051 acc_train: 0.6786 acc_val: 0.7540 acc_test: 0.7750 time: 0.0318s
# Epoch: 0134 loss_train: 1.1320 acc_train: 0.6571 acc_val: 0.7620 acc_test: 0.7870 time: 0.0258s
# Epoch: 0135 loss_train: 1.0854 acc_train: 0.6571 acc_val: 0.7660 acc_test: 0.7970 time: 0.0317s
# Epoch: 0136 loss_train: 1.1919 acc_train: 0.5571 acc_val: 0.7700 acc_test: 0.8030 time: 0.0304s
# Epoch: 0137 loss_train: 1.2023 acc_train: 0.6071 acc_val: 0.7760 acc_test: 0.8150 time: 0.0289s
# Epoch: 0138 loss_train: 1.0875 acc_train: 0.6214 acc_val: 0.7820 acc_test: 0.8200 time: 0.0329s
# Epoch: 0139 loss_train: 0.9890 acc_train: 0.7143 acc_val: 0.7880 acc_test: 0.8170 time: 0.0307s
# Epoch: 0140 loss_train: 1.1134 acc_train: 0.6214 acc_val: 0.7880 acc_test: 0.8150 time: 0.0303s
# Epoch: 0141 loss_train: 0.9945 acc_train: 0.6857 acc_val: 0.7920 acc_test: 0.8150 time: 0.0297s
# Epoch: 0142 loss_train: 0.9856 acc_train: 0.6714 acc_val: 0.7960 acc_test: 0.8200 time: 0.0308s
# Epoch: 0143 loss_train: 0.9132 acc_train: 0.7071 acc_val: 0.7960 acc_test: 0.8240 time: 0.0295s
# Epoch: 0144 loss_train: 1.0745 acc_train: 0.6786 acc_val: 0.8000 acc_test: 0.8270 time: 0.0303s
# Epoch: 0145 loss_train: 0.9339 acc_train: 0.7357 acc_val: 0.7980 acc_test: 0.8290 time: 0.0256s
# Epoch: 0146 loss_train: 1.0383 acc_train: 0.6500 acc_val: 0.7960 acc_test: 0.8250 time: 0.0307s
# Epoch: 0147 loss_train: 1.2074 acc_train: 0.6071 acc_val: 0.7920 acc_test: 0.8170 time: 0.0257s
# Epoch: 0148 loss_train: 1.0840 acc_train: 0.6786 acc_val: 0.7820 acc_test: 0.8000 time: 0.0321s
# Epoch: 0149 loss_train: 1.1909 acc_train: 0.5929 acc_val: 0.7680 acc_test: 0.7930 time: 0.0307s
# Epoch: 0150 loss_train: 1.1692 acc_train: 0.6214 acc_val: 0.7560 acc_test: 0.7910 time: 0.0289s
# Epoch: 0151 loss_train: 1.0695 acc_train: 0.6286 acc_val: 0.7520 acc_test: 0.7770 time: 0.0322s
# Epoch: 0152 loss_train: 0.9502 acc_train: 0.7357 acc_val: 0.7520 acc_test: 0.7810 time: 0.0303s
# Epoch: 0153 loss_train: 1.0249 acc_train: 0.6786 acc_val: 0.7560 acc_test: 0.7890 time: 0.0292s
# Epoch: 0154 loss_train: 0.9874 acc_train: 0.7214 acc_val: 0.7640 acc_test: 0.7940 time: 0.0304s
# Epoch: 0155 loss_train: 0.9983 acc_train: 0.7000 acc_val: 0.7700 acc_test: 0.7990 time: 0.0305s
# Epoch: 0156 loss_train: 1.0903 acc_train: 0.6786 acc_val: 0.7760 acc_test: 0.8100 time: 0.0316s
# Epoch: 0157 loss_train: 1.0553 acc_train: 0.6786 acc_val: 0.7920 acc_test: 0.8120 time: 0.0299s
# Epoch: 0158 loss_train: 1.0600 acc_train: 0.6214 acc_val: 0.8000 acc_test: 0.8080 time: 0.0305s
# Epoch: 0159 loss_train: 1.0956 acc_train: 0.6786 acc_val: 0.7960 acc_test: 0.8100 time: 0.0296s
# Epoch: 0160 loss_train: 1.1301 acc_train: 0.6429 acc_val: 0.7940 acc_test: 0.8070 time: 0.0301s
# Epoch: 0161 loss_train: 0.9941 acc_train: 0.6857 acc_val: 0.7720 acc_test: 0.8050 time: 0.0305s
# Epoch: 0162 loss_train: 1.0746 acc_train: 0.6571 acc_val: 0.7660 acc_test: 0.7920 time: 0.0293s
# Epoch: 0163 loss_train: 1.0358 acc_train: 0.6357 acc_val: 0.7600 acc_test: 0.7870 time: 0.0323s
# Epoch: 0164 loss_train: 1.1065 acc_train: 0.6786 acc_val: 0.7580 acc_test: 0.7830 time: 0.0309s
# Epoch: 0165 loss_train: 0.9909 acc_train: 0.7214 acc_val: 0.7560 acc_test: 0.7870 time: 0.0297s
# Epoch: 0166 loss_train: 0.9397 acc_train: 0.7000 acc_val: 0.7580 acc_test: 0.7850 time: 0.0301s
# Epoch: 0167 loss_train: 1.1124 acc_train: 0.6286 acc_val: 0.7620 acc_test: 0.7870 time: 0.0307s
# Epoch: 0168 loss_train: 1.0994 acc_train: 0.6714 acc_val: 0.7620 acc_test: 0.7860 time: 0.0294s
# Epoch: 0169 loss_train: 1.0006 acc_train: 0.6786 acc_val: 0.7720 acc_test: 0.7930 time: 0.0303s
# Epoch: 0170 loss_train: 0.9560 acc_train: 0.6643 acc_val: 0.7740 acc_test: 0.8000 time: 0.0258s
# Epoch: 0171 loss_train: 0.8950 acc_train: 0.7286 acc_val: 0.7840 acc_test: 0.8110 time: 0.0318s
# Epoch: 0172 loss_train: 1.0352 acc_train: 0.6786 acc_val: 0.7860 acc_test: 0.8140 time: 0.0306s
# Epoch: 0173 loss_train: 1.0068 acc_train: 0.7071 acc_val: 0.7920 acc_test: 0.8160 time: 0.0292s
# Epoch: 0174 loss_train: 1.0892 acc_train: 0.6286 acc_val: 0.7960 acc_test: 0.8170 time: 0.0305s
# Epoch: 0175 loss_train: 0.8900 acc_train: 0.7214 acc_val: 0.7920 acc_test: 0.8060 time: 0.0260s
# Epoch: 0176 loss_train: 0.9586 acc_train: 0.7071 acc_val: 0.7940 acc_test: 0.8100 time: 0.0320s
# Epoch: 0177 loss_train: 1.0041 acc_train: 0.7071 acc_val: 0.7780 acc_test: 0.8040 time: 0.0308s
# Epoch: 0178 loss_train: 0.9205 acc_train: 0.7214 acc_val: 0.7740 acc_test: 0.8030 time: 0.0297s
# Epoch: 0179 loss_train: 0.9908 acc_train: 0.6000 acc_val: 0.7760 acc_test: 0.8020 time: 0.0301s
# Epoch: 0180 loss_train: 1.0066 acc_train: 0.6643 acc_val: 0.7700 acc_test: 0.8020 time: 0.0304s
# Epoch: 0181 loss_train: 0.9928 acc_train: 0.6786 acc_val: 0.7660 acc_test: 0.8020 time: 0.0295s
# Epoch: 0182 loss_train: 0.9782 acc_train: 0.6786 acc_val: 0.7720 acc_test: 0.8060 time: 0.0303s
# Epoch: 0183 loss_train: 0.9688 acc_train: 0.6929 acc_val: 0.7780 acc_test: 0.8030 time: 0.0303s
# Epoch: 0184 loss_train: 0.9624 acc_train: 0.7071 acc_val: 0.7840 acc_test: 0.8040 time: 0.0288s
# Epoch: 0185 loss_train: 0.9866 acc_train: 0.6857 acc_val: 0.7900 acc_test: 0.8120 time: 0.0323s
# Epoch: 0186 loss_train: 0.9964 acc_train: 0.6429 acc_val: 0.7920 acc_test: 0.8160 time: 0.0306s
# Epoch: 0187 loss_train: 1.0849 acc_train: 0.6214 acc_val: 0.7980 acc_test: 0.8240 time: 0.0298s
# Epoch: 0188 loss_train: 1.0860 acc_train: 0.6429 acc_val: 0.7960 acc_test: 0.8230 time: 0.0300s
# Epoch: 0189 loss_train: 1.0138 acc_train: 0.7000 acc_val: 0.7940 acc_test: 0.8250 time: 0.0306s
# Epoch: 0190 loss_train: 0.9713 acc_train: 0.7714 acc_val: 0.7900 acc_test: 0.8170 time: 0.0296s
# Epoch: 0191 loss_train: 0.9346 acc_train: 0.7143 acc_val: 0.7880 acc_test: 0.8170 time: 0.0304s
# Epoch: 0192 loss_train: 0.9527 acc_train: 0.6786 acc_val: 0.7880 acc_test: 0.8090 time: 0.0303s
# Epoch: 0193 loss_train: 0.9202 acc_train: 0.6786 acc_val: 0.7880 acc_test: 0.8050 time: 0.0289s
# Epoch: 0194 loss_train: 1.0306 acc_train: 0.6429 acc_val: 0.7800 acc_test: 0.8090 time: 0.0330s
# Epoch: 0195 loss_train: 0.9339 acc_train: 0.6786 acc_val: 0.7800 acc_test: 0.8080 time: 0.0307s
# Epoch: 0196 loss_train: 0.9507 acc_train: 0.6786 acc_val: 0.7720 acc_test: 0.8060 time: 0.0300s
# Epoch: 0197 loss_train: 0.8407 acc_train: 0.7286 acc_val: 0.7720 acc_test: 0.8020 time: 0.0298s
# Epoch: 0198 loss_train: 0.9690 acc_train: 0.6643 acc_val: 0.7700 acc_test: 0.8010 time: 0.0306s
# Epoch: 0199 loss_train: 0.8794 acc_train: 0.7214 acc_val: 0.7740 acc_test: 0.8010 time: 0.0296s
# Epoch: 0200 loss_train: 0.8996 acc_train: 0.6786 acc_val: 0.7780 acc_test: 0.7970 time: 0.0302s
# Epoch: 0201 loss_train: 0.9381 acc_train: 0.7000 acc_val: 0.7900 acc_test: 0.8040 time: 0.0306s
# Epoch: 0202 loss_train: 0.9531 acc_train: 0.7500 acc_val: 0.7980 acc_test: 0.8060 time: 0.0291s
# Epoch: 0203 loss_train: 0.9481 acc_train: 0.6929 acc_val: 0.7960 acc_test: 0.8150 time: 0.0309s
# Epoch: 0204 loss_train: 0.8711 acc_train: 0.7357 acc_val: 0.7980 acc_test: 0.8160 time: 0.0306s
# Epoch: 0205 loss_train: 0.9628 acc_train: 0.6786 acc_val: 0.7940 acc_test: 0.8200 time: 0.0293s
# Epoch: 0206 loss_train: 0.9658 acc_train: 0.7143 acc_val: 0.7980 acc_test: 0.8250 time: 0.0322s
# Epoch: 0207 loss_train: 1.2902 acc_train: 0.6786 acc_val: 0.7880 acc_test: 0.8160 time: 0.0305s
# Epoch: 0208 loss_train: 0.9205 acc_train: 0.7357 acc_val: 0.7840 acc_test: 0.8100 time: 0.0297s
# Epoch: 0209 loss_train: 0.9445 acc_train: 0.7214 acc_val: 0.7860 acc_test: 0.8060 time: 0.0299s
# Epoch: 0210 loss_train: 0.8442 acc_train: 0.7214 acc_val: 0.7880 acc_test: 0.8070 time: 0.0306s
# Epoch: 0211 loss_train: 0.7951 acc_train: 0.7500 acc_val: 0.7920 acc_test: 0.8110 time: 0.0299s
# Epoch: 0212 loss_train: 0.9715 acc_train: 0.6643 acc_val: 0.7920 acc_test: 0.8100 time: 0.0299s
# Epoch: 0213 loss_train: 0.9957 acc_train: 0.6643 acc_val: 0.7940 acc_test: 0.8060 time: 0.0305s
# Epoch: 0214 loss_train: 0.8487 acc_train: 0.7214 acc_val: 0.7960 acc_test: 0.8080 time: 0.0290s
# Epoch: 0215 loss_train: 0.9968 acc_train: 0.6571 acc_val: 0.7880 acc_test: 0.8090 time: 0.0322s
# Epoch: 0216 loss_train: 1.0113 acc_train: 0.6714 acc_val: 0.7880 acc_test: 0.8100 time: 0.0305s
# Epoch: 0217 loss_train: 0.8355 acc_train: 0.7857 acc_val: 0.7940 acc_test: 0.8110 time: 0.0296s
# Epoch: 0218 loss_train: 1.0327 acc_train: 0.6571 acc_val: 0.7940 acc_test: 0.8120 time: 0.0301s
# Epoch: 0219 loss_train: 0.9512 acc_train: 0.6429 acc_val: 0.7920 acc_test: 0.8110 time: 0.0306s
# Epoch: 0220 loss_train: 0.9097 acc_train: 0.7071 acc_val: 0.7920 acc_test: 0.8110 time: 0.0295s
# Epoch: 0221 loss_train: 0.8744 acc_train: 0.7071 acc_val: 0.7940 acc_test: 0.8140 time: 0.0303s
# Epoch: 0222 loss_train: 0.7875 acc_train: 0.7786 acc_val: 0.8040 acc_test: 0.8160 time: 0.0257s
# Epoch: 0223 loss_train: 0.8782 acc_train: 0.7643 acc_val: 0.8020 acc_test: 0.8180 time: 0.0340s
# Epoch: 0224 loss_train: 0.8557 acc_train: 0.7571 acc_val: 0.8040 acc_test: 0.8170 time: 0.0287s
# Epoch: 0225 loss_train: 0.8516 acc_train: 0.7214 acc_val: 0.8040 acc_test: 0.8210 time: 0.0267s
# Epoch: 0226 loss_train: 0.9376 acc_train: 0.6786 acc_val: 0.8020 acc_test: 0.8200 time: 0.0319s
# Epoch: 0227 loss_train: 0.9722 acc_train: 0.6500 acc_val: 0.8020 acc_test: 0.8260 time: 0.0257s
# Epoch: 0228 loss_train: 0.8570 acc_train: 0.7071 acc_val: 0.8020 acc_test: 0.8280 time: 0.0316s
# Epoch: 0229 loss_train: 0.9201 acc_train: 0.6929 acc_val: 0.8040 acc_test: 0.8330 time: 0.0258s
# Epoch: 0230 loss_train: 0.9116 acc_train: 0.7071 acc_val: 0.8020 acc_test: 0.8320 time: 0.0317s
# Epoch: 0231 loss_train: 0.9026 acc_train: 0.7500 acc_val: 0.7980 acc_test: 0.8340 time: 0.0306s
# Epoch: 0232 loss_train: 0.8503 acc_train: 0.6857 acc_val: 0.7960 acc_test: 0.8240 time: 0.0296s
# Epoch: 0233 loss_train: 0.8446 acc_train: 0.7429 acc_val: 0.7980 acc_test: 0.8220 time: 0.0302s
# Epoch: 0234 loss_train: 0.8053 acc_train: 0.7571 acc_val: 0.7980 acc_test: 0.8210 time: 0.0305s
# Epoch: 0235 loss_train: 0.9833 acc_train: 0.7071 acc_val: 0.8000 acc_test: 0.8220 time: 0.0289s
# Epoch: 0236 loss_train: 0.8763 acc_train: 0.7357 acc_val: 0.7980 acc_test: 0.8180 time: 0.0323s
# Epoch: 0237 loss_train: 0.9202 acc_train: 0.7000 acc_val: 0.8020 acc_test: 0.8180 time: 0.0306s
# Epoch: 0238 loss_train: 0.7884 acc_train: 0.7786 acc_val: 0.8020 acc_test: 0.8160 time: 0.0296s
# Epoch: 0239 loss_train: 0.9022 acc_train: 0.7000 acc_val: 0.7980 acc_test: 0.8200 time: 0.0314s
# Epoch: 0240 loss_train: 0.8147 acc_train: 0.7929 acc_val: 0.7960 acc_test: 0.8220 time: 0.0307s
# Epoch: 0241 loss_train: 0.8443 acc_train: 0.7071 acc_val: 0.7980 acc_test: 0.8260 time: 0.0302s
# Epoch: 0242 loss_train: 0.9176 acc_train: 0.7357 acc_val: 0.8000 acc_test: 0.8260 time: 0.0285s
# Epoch: 0243 loss_train: 0.8504 acc_train: 0.6714 acc_val: 0.7980 acc_test: 0.8240 time: 0.0305s
# Epoch: 0244 loss_train: 0.6871 acc_train: 0.7786 acc_val: 0.8020 acc_test: 0.8200 time: 0.0291s
# Epoch: 0245 loss_train: 0.7433 acc_train: 0.7857 acc_val: 0.8000 acc_test: 0.8130 time: 0.0323s
# Epoch: 0246 loss_train: 0.9052 acc_train: 0.6857 acc_val: 0.7980 acc_test: 0.8160 time: 0.0308s
# Epoch: 0247 loss_train: 0.7718 acc_train: 0.7429 acc_val: 0.7940 acc_test: 0.8160 time: 0.0300s
# Epoch: 0248 loss_train: 0.8939 acc_train: 0.7214 acc_val: 0.7920 acc_test: 0.8190 time: 0.0298s
# Epoch: 0249 loss_train: 0.8115 acc_train: 0.7286 acc_val: 0.7900 acc_test: 0.8210 time: 0.0307s
# Epoch: 0250 loss_train: 0.9050 acc_train: 0.7143 acc_val: 0.7860 acc_test: 0.8240 time: 0.0296s
# Epoch: 0251 loss_train: 0.8460 acc_train: 0.6929 acc_val: 0.7840 acc_test: 0.8160 time: 0.0300s
# Epoch: 0252 loss_train: 0.9123 acc_train: 0.7000 acc_val: 0.7780 acc_test: 0.8050 time: 0.0307s
# Epoch: 0253 loss_train: 0.9549 acc_train: 0.6714 acc_val: 0.7780 acc_test: 0.8020 time: 0.0290s
# Epoch: 0254 loss_train: 0.8881 acc_train: 0.6857 acc_val: 0.7800 acc_test: 0.7960 time: 0.0305s
# Epoch: 0255 loss_train: 0.8264 acc_train: 0.7071 acc_val: 0.7760 acc_test: 0.7860 time: 0.0258s
# Epoch: 0256 loss_train: 0.8383 acc_train: 0.7571 acc_val: 0.7660 acc_test: 0.7870 time: 0.0327s
# Epoch: 0257 loss_train: 0.7796 acc_train: 0.7857 acc_val: 0.7660 acc_test: 0.7870 time: 0.0314s
# Epoch: 0258 loss_train: 0.8233 acc_train: 0.7357 acc_val: 0.7800 acc_test: 0.7970 time: 0.0302s
# Epoch: 0259 loss_train: 0.9297 acc_train: 0.7000 acc_val: 0.7980 acc_test: 0.8150 time: 0.0282s
# Epoch: 0260 loss_train: 0.8767 acc_train: 0.7357 acc_val: 0.7960 acc_test: 0.8280 time: 0.0306s
# Epoch: 0261 loss_train: 0.9462 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8290 time: 0.0290s
# Epoch: 0262 loss_train: 0.7107 acc_train: 0.8357 acc_val: 0.8000 acc_test: 0.8320 time: 0.0324s
# Epoch: 0263 loss_train: 0.8714 acc_train: 0.7643 acc_val: 0.8000 acc_test: 0.8340 time: 0.0306s
# Epoch: 0264 loss_train: 0.7746 acc_train: 0.7429 acc_val: 0.8020 acc_test: 0.8340 time: 0.0295s
# Epoch: 0265 loss_train: 0.8796 acc_train: 0.7286 acc_val: 0.7960 acc_test: 0.8320 time: 0.0290s
# Epoch: 0266 loss_train: 0.9281 acc_train: 0.6786 acc_val: 0.7900 acc_test: 0.8260 time: 0.0257s
# Epoch: 0267 loss_train: 0.7721 acc_train: 0.7357 acc_val: 0.7820 acc_test: 0.8160 time: 0.0319s
# Epoch: 0268 loss_train: 1.0591 acc_train: 0.6571 acc_val: 0.7920 acc_test: 0.8020 time: 0.0304s
# Epoch: 0269 loss_train: 0.9495 acc_train: 0.6357 acc_val: 0.7900 acc_test: 0.7900 time: 0.0285s
# Epoch: 0270 loss_train: 0.9610 acc_train: 0.6500 acc_val: 0.7840 acc_test: 0.7820 time: 0.0331s
# Epoch: 0271 loss_train: 0.9499 acc_train: 0.6857 acc_val: 0.7800 acc_test: 0.7740 time: 0.0305s
# Epoch: 0272 loss_train: 0.9585 acc_train: 0.6143 acc_val: 0.7760 acc_test: 0.7800 time: 0.0299s
# Epoch: 0273 loss_train: 0.8502 acc_train: 0.7429 acc_val: 0.7740 acc_test: 0.7830 time: 0.0300s
# Epoch: 0274 loss_train: 0.9972 acc_train: 0.6786 acc_val: 0.7760 acc_test: 0.7910 time: 0.0303s
# Epoch: 0275 loss_train: 0.8353 acc_train: 0.7357 acc_val: 0.7880 acc_test: 0.8060 time: 0.0290s
# Epoch: 0276 loss_train: 0.7987 acc_train: 0.7571 acc_val: 0.7940 acc_test: 0.8090 time: 0.0325s
# Epoch: 0277 loss_train: 0.8196 acc_train: 0.7714 acc_val: 0.7940 acc_test: 0.8110 time: 0.0306s
# Epoch: 0278 loss_train: 0.8312 acc_train: 0.7643 acc_val: 0.7900 acc_test: 0.8210 time: 0.0294s
# Epoch: 0279 loss_train: 0.8826 acc_train: 0.7286 acc_val: 0.7960 acc_test: 0.8270 time: 0.0305s
# Epoch: 0280 loss_train: 0.8351 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8250 time: 0.0258s
# Epoch: 0281 loss_train: 0.8190 acc_train: 0.7286 acc_val: 0.7960 acc_test: 0.8260 time: 0.0318s
# Epoch: 0282 loss_train: 0.9148 acc_train: 0.6929 acc_val: 0.7940 acc_test: 0.8260 time: 0.0306s
# Epoch: 0283 loss_train: 0.8079 acc_train: 0.7429 acc_val: 0.8000 acc_test: 0.8200 time: 0.0295s
# Epoch: 0284 loss_train: 0.8152 acc_train: 0.7714 acc_val: 0.7940 acc_test: 0.8190 time: 0.0303s
# Epoch: 0285 loss_train: 0.7131 acc_train: 0.7929 acc_val: 0.8000 acc_test: 0.8080 time: 0.0304s
# Epoch: 0286 loss_train: 0.8360 acc_train: 0.7214 acc_val: 0.8020 acc_test: 0.8020 time: 0.0289s
# Epoch: 0287 loss_train: 0.8790 acc_train: 0.7143 acc_val: 0.8000 acc_test: 0.8100 time: 0.0330s
# Epoch: 0288 loss_train: 0.7412 acc_train: 0.7786 acc_val: 0.7980 acc_test: 0.8170 time: 0.0305s
# Epoch: 0289 loss_train: 0.8754 acc_train: 0.7286 acc_val: 0.7920 acc_test: 0.8230 time: 0.0294s
# Epoch: 0290 loss_train: 0.8936 acc_train: 0.6643 acc_val: 0.7920 acc_test: 0.8210 time: 0.0303s
# Epoch: 0291 loss_train: 0.7820 acc_train: 0.7571 acc_val: 0.7940 acc_test: 0.8250 time: 0.0306s
# Epoch: 0292 loss_train: 0.8251 acc_train: 0.7286 acc_val: 0.7980 acc_test: 0.8270 time: 0.0290s
# Epoch: 0293 loss_train: 0.8292 acc_train: 0.7286 acc_val: 0.7960 acc_test: 0.8220 time: 0.0324s
# Epoch: 0294 loss_train: 0.7315 acc_train: 0.7500 acc_val: 0.7940 acc_test: 0.8190 time: 0.0283s
# Epoch: 0295 loss_train: 0.9851 acc_train: 0.6929 acc_val: 0.8000 acc_test: 0.8150 time: 0.0288s
# Epoch: 0296 loss_train: 0.9273 acc_train: 0.6429 acc_val: 0.8020 acc_test: 0.8170 time: 0.0304s
# Epoch: 0297 loss_train: 0.9117 acc_train: 0.7143 acc_val: 0.8040 acc_test: 0.8100 time: 0.0294s
# Epoch: 0298 loss_train: 0.9190 acc_train: 0.7000 acc_val: 0.8020 acc_test: 0.8070 time: 0.0301s
# Epoch: 0299 loss_train: 0.8254 acc_train: 0.7571 acc_val: 0.7960 acc_test: 0.8070 time: 0.0306s
# Epoch: 0300 loss_train: 0.8327 acc_train: 0.7571 acc_val: 0.7920 acc_test: 0.8060 time: 0.0295s
# Epoch: 0301 loss_train: 0.8137 acc_train: 0.7571 acc_val: 0.7860 acc_test: 0.8100 time: 0.0303s
# Epoch: 0302 loss_train: 0.8550 acc_train: 0.7000 acc_val: 0.7940 acc_test: 0.8150 time: 0.0259s
# Epoch: 0303 loss_train: 0.8946 acc_train: 0.7429 acc_val: 0.7920 acc_test: 0.8200 time: 0.0320s
# Epoch: 0304 loss_train: 0.8257 acc_train: 0.7643 acc_val: 0.7900 acc_test: 0.8210 time: 0.0307s
# Epoch: 0305 loss_train: 0.9511 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8210 time: 0.0294s
# Epoch: 0306 loss_train: 0.8668 acc_train: 0.6929 acc_val: 0.7980 acc_test: 0.8270 time: 0.0304s
# Epoch: 0307 loss_train: 0.8424 acc_train: 0.7643 acc_val: 0.8020 acc_test: 0.8310 time: 0.0307s
# Epoch: 0308 loss_train: 0.8754 acc_train: 0.6929 acc_val: 0.8020 acc_test: 0.8300 time: 0.0290s
# Epoch: 0309 loss_train: 0.9083 acc_train: 0.6571 acc_val: 0.8000 acc_test: 0.8170 time: 0.0322s
# Epoch: 0310 loss_train: 0.8554 acc_train: 0.7571 acc_val: 0.7980 acc_test: 0.8070 time: 0.0305s
# Epoch: 0311 loss_train: 0.9140 acc_train: 0.6786 acc_val: 0.7880 acc_test: 0.8000 time: 0.0293s
# Epoch: 0312 loss_train: 0.7869 acc_train: 0.7643 acc_val: 0.7840 acc_test: 0.7930 time: 0.0304s
# Epoch: 0313 loss_train: 0.8243 acc_train: 0.7500 acc_val: 0.7840 acc_test: 0.7940 time: 0.0258s
# Epoch: 0314 loss_train: 0.7731 acc_train: 0.7571 acc_val: 0.7840 acc_test: 0.7930 time: 0.0293s
# Epoch: 0315 loss_train: 0.8219 acc_train: 0.7286 acc_val: 0.7740 acc_test: 0.7910 time: 0.0257s
# Epoch: 0316 loss_train: 0.9267 acc_train: 0.6643 acc_val: 0.7800 acc_test: 0.7970 time: 0.0318s
# Epoch: 0317 loss_train: 0.7877 acc_train: 0.7286 acc_val: 0.7820 acc_test: 0.8010 time: 0.0258s
# Epoch: 0318 loss_train: 0.8396 acc_train: 0.7357 acc_val: 0.7840 acc_test: 0.8100 time: 0.0318s
# Epoch: 0319 loss_train: 0.9130 acc_train: 0.7071 acc_val: 0.7860 acc_test: 0.8150 time: 0.0306s
# Epoch: 0320 loss_train: 0.8718 acc_train: 0.7286 acc_val: 0.7800 acc_test: 0.8140 time: 0.0290s
# Epoch: 0321 loss_train: 0.9201 acc_train: 0.6500 acc_val: 0.7920 acc_test: 0.8180 time: 0.0325s
# Epoch: 0322 loss_train: 0.9825 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8220 time: 0.0305s
# Epoch: 0323 loss_train: 0.9132 acc_train: 0.7000 acc_val: 0.7960 acc_test: 0.8150 time: 0.0296s
# Epoch: 0324 loss_train: 0.8257 acc_train: 0.7357 acc_val: 0.7900 acc_test: 0.8140 time: 0.0300s
# Epoch: 0325 loss_train: 0.8173 acc_train: 0.7786 acc_val: 0.7960 acc_test: 0.8040 time: 0.0257s
# Epoch: 0326 loss_train: 0.8850 acc_train: 0.6786 acc_val: 0.7900 acc_test: 0.8030 time: 0.0321s
# Epoch: 0327 loss_train: 0.7815 acc_train: 0.7357 acc_val: 0.7840 acc_test: 0.8000 time: 0.0304s
# Epoch: 0328 loss_train: 0.8573 acc_train: 0.7643 acc_val: 0.7840 acc_test: 0.8010 time: 0.0297s
# Epoch: 0329 loss_train: 0.8118 acc_train: 0.7429 acc_val: 0.7820 acc_test: 0.7990 time: 0.0302s
# Epoch: 0330 loss_train: 0.8386 acc_train: 0.6929 acc_val: 0.7820 acc_test: 0.8000 time: 0.0256s
# Epoch: 0331 loss_train: 0.8501 acc_train: 0.7143 acc_val: 0.7800 acc_test: 0.8040 time: 0.0317s
# Epoch: 0332 loss_train: 0.9363 acc_train: 0.6714 acc_val: 0.7940 acc_test: 0.8080 time: 0.0307s
# Epoch: 0333 loss_train: 0.9627 acc_train: 0.6929 acc_val: 0.7920 acc_test: 0.8100 time: 0.0290s
# Epoch: 0334 loss_train: 0.8674 acc_train: 0.7714 acc_val: 0.7900 acc_test: 0.8110 time: 0.0322s
# Epoch: 0335 loss_train: 0.7607 acc_train: 0.7500 acc_val: 0.7900 acc_test: 0.8150 time: 0.0307s
# Epoch: 0336 loss_train: 0.7716 acc_train: 0.7786 acc_val: 0.7940 acc_test: 0.8220 time: 0.0303s
# Epoch: 0337 loss_train: 0.8102 acc_train: 0.7500 acc_val: 0.7900 acc_test: 0.8210 time: 0.0284s
# Epoch: 0338 loss_train: 0.9882 acc_train: 0.7071 acc_val: 0.7920 acc_test: 0.8160 time: 0.0306s
# Epoch: 0339 loss_train: 0.9043 acc_train: 0.7214 acc_val: 0.7880 acc_test: 0.8120 time: 0.0292s
# Epoch: 0340 loss_train: 0.7911 acc_train: 0.7643 acc_val: 0.7880 acc_test: 0.8060 time: 0.0305s
# Epoch: 0341 loss_train: 0.7744 acc_train: 0.7857 acc_val: 0.7880 acc_test: 0.8110 time: 0.0259s
# Epoch: 0342 loss_train: 0.7455 acc_train: 0.7571 acc_val: 0.7960 acc_test: 0.8100 time: 0.0318s
# Epoch: 0343 loss_train: 0.8609 acc_train: 0.7500 acc_val: 0.7940 acc_test: 0.8200 time: 0.0306s
# Epoch: 0344 loss_train: 0.9122 acc_train: 0.7143 acc_val: 0.7960 acc_test: 0.8180 time: 0.0290s
# Epoch: 0345 loss_train: 0.7598 acc_train: 0.7643 acc_val: 0.7940 acc_test: 0.8180 time: 0.0325s
# Epoch: 0346 loss_train: 0.8548 acc_train: 0.7357 acc_val: 0.7940 acc_test: 0.8190 time: 0.0305s
# Epoch: 0347 loss_train: 0.8284 acc_train: 0.6929 acc_val: 0.8040 acc_test: 0.8200 time: 0.0344s
# Epoch: 0348 loss_train: 0.8549 acc_train: 0.7071 acc_val: 0.8020 acc_test: 0.8210 time: 0.0318s
# Epoch: 0349 loss_train: 0.6521 acc_train: 0.8000 acc_val: 0.8000 acc_test: 0.8210 time: 0.0293s
# Epoch: 0350 loss_train: 0.8216 acc_train: 0.7500 acc_val: 0.7980 acc_test: 0.8170 time: 0.0309s
# Epoch: 0351 loss_train: 0.8140 acc_train: 0.7286 acc_val: 0.7980 acc_test: 0.8080 time: 0.0301s
# Epoch: 0352 loss_train: 0.8211 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8050 time: 0.0314s
# Epoch: 0353 loss_train: 0.7620 acc_train: 0.7500 acc_val: 0.7900 acc_test: 0.8000 time: 0.0285s
# Epoch: 0354 loss_train: 0.8957 acc_train: 0.7071 acc_val: 0.7840 acc_test: 0.7960 time: 0.0268s
# Epoch: 0355 loss_train: 0.8280 acc_train: 0.7500 acc_val: 0.7840 acc_test: 0.7950 time: 0.0319s
# Epoch: 0356 loss_train: 0.8239 acc_train: 0.7643 acc_val: 0.7920 acc_test: 0.8030 time: 0.0259s
# Epoch: 0357 loss_train: 0.7787 acc_train: 0.7500 acc_val: 0.7920 acc_test: 0.8090 time: 0.0318s
# Epoch: 0358 loss_train: 0.7889 acc_train: 0.7071 acc_val: 0.8000 acc_test: 0.8190 time: 0.0306s
# Epoch: 0359 loss_train: 0.9417 acc_train: 0.7571 acc_val: 0.8000 acc_test: 0.8260 time: 0.0353s
# Epoch: 0360 loss_train: 0.8241 acc_train: 0.7071 acc_val: 0.7980 acc_test: 0.8330 time: 0.0268s
# Epoch: 0361 loss_train: 0.8145 acc_train: 0.7500 acc_val: 0.8000 acc_test: 0.8350 time: 0.0319s
# Epoch: 0362 loss_train: 0.8813 acc_train: 0.7000 acc_val: 0.8060 acc_test: 0.8350 time: 0.0268s
# Epoch: 0363 loss_train: 0.8079 acc_train: 0.7357 acc_val: 0.8040 acc_test: 0.8330 time: 0.0318s
# Epoch: 0364 loss_train: 0.8521 acc_train: 0.7357 acc_val: 0.8080 acc_test: 0.8280 time: 0.0286s
# Epoch: 0365 loss_train: 0.7034 acc_train: 0.7429 acc_val: 0.8020 acc_test: 0.8240 time: 0.0298s
# Epoch: 0366 loss_train: 0.8372 acc_train: 0.7286 acc_val: 0.8000 acc_test: 0.8160 time: 0.0258s
# Epoch: 0367 loss_train: 0.7171 acc_train: 0.7857 acc_val: 0.8020 acc_test: 0.8130 time: 0.0317s
# Epoch: 0368 loss_train: 0.8240 acc_train: 0.7143 acc_val: 0.8040 acc_test: 0.8150 time: 0.0267s
# Epoch: 0369 loss_train: 0.7457 acc_train: 0.7571 acc_val: 0.8060 acc_test: 0.8240 time: 0.0289s
# Epoch: 0370 loss_train: 0.9346 acc_train: 0.7500 acc_val: 0.8020 acc_test: 0.8210 time: 0.0257s
# Epoch: 0371 loss_train: 0.8690 acc_train: 0.7143 acc_val: 0.8000 acc_test: 0.8200 time: 0.0303s
# Epoch: 0372 loss_train: 0.8416 acc_train: 0.7571 acc_val: 0.7980 acc_test: 0.8240 time: 0.0308s
# Epoch: 0373 loss_train: 0.7635 acc_train: 0.7929 acc_val: 0.7980 acc_test: 0.8210 time: 0.0306s
# Epoch: 0374 loss_train: 0.7367 acc_train: 0.8000 acc_val: 0.7960 acc_test: 0.8190 time: 0.0338s
# Epoch: 0375 loss_train: 0.8120 acc_train: 0.7786 acc_val: 0.7940 acc_test: 0.8200 time: 0.0269s
# Epoch: 0376 loss_train: 0.8319 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8220 time: 0.0321s
# Epoch: 0377 loss_train: 0.8159 acc_train: 0.7571 acc_val: 0.7940 acc_test: 0.8200 time: 0.0257s
# Epoch: 0378 loss_train: 0.8472 acc_train: 0.7429 acc_val: 0.7940 acc_test: 0.8210 time: 0.0314s
# Epoch: 0379 loss_train: 0.7693 acc_train: 0.7714 acc_val: 0.7980 acc_test: 0.8240 time: 0.0326s
# Epoch: 0380 loss_train: 0.8006 acc_train: 0.7429 acc_val: 0.7980 acc_test: 0.8210 time: 0.0286s
# Epoch: 0381 loss_train: 0.7890 acc_train: 0.7214 acc_val: 0.7940 acc_test: 0.8170 time: 0.0331s
# Epoch: 0382 loss_train: 0.7769 acc_train: 0.7786 acc_val: 0.7920 acc_test: 0.8160 time: 0.0257s
# Epoch: 0383 loss_train: 0.9113 acc_train: 0.7000 acc_val: 0.7900 acc_test: 0.8120 time: 0.0321s
# Epoch: 0384 loss_train: 0.8093 acc_train: 0.7571 acc_val: 0.7920 acc_test: 0.8150 time: 0.0257s
# Epoch: 0385 loss_train: 0.7990 acc_train: 0.7286 acc_val: 0.7940 acc_test: 0.8230 time: 0.0316s
# Epoch: 0386 loss_train: 1.1447 acc_train: 0.7000 acc_val: 0.8000 acc_test: 0.8270 time: 0.0260s
# Epoch: 0387 loss_train: 0.9172 acc_train: 0.7286 acc_val: 0.8100 acc_test: 0.8350 time: 0.0317s
# Epoch: 0388 loss_train: 0.7355 acc_train: 0.7643 acc_val: 0.8140 acc_test: 0.8400 time: 0.0306s
# Epoch: 0389 loss_train: 0.7556 acc_train: 0.7643 acc_val: 0.8080 acc_test: 0.8460 time: 0.0293s
# Epoch: 0390 loss_train: 0.7792 acc_train: 0.7643 acc_val: 0.8160 acc_test: 0.8430 time: 0.0310s
# Epoch: 0391 loss_train: 2.0195 acc_train: 0.7214 acc_val: 0.8080 acc_test: 0.8420 time: 0.0306s
# Epoch: 0392 loss_train: 0.7226 acc_train: 0.8286 acc_val: 0.8120 acc_test: 0.8330 time: 0.0291s
# Epoch: 0393 loss_train: 0.8390 acc_train: 0.7357 acc_val: 0.8060 acc_test: 0.8340 time: 0.0321s
# Epoch: 0394 loss_train: 0.8507 acc_train: 0.7571 acc_val: 0.8140 acc_test: 0.8310 time: 0.0305s
# Epoch: 0395 loss_train: 0.7848 acc_train: 0.7571 acc_val: 0.8140 acc_test: 0.8240 time: 0.0300s
# Epoch: 0396 loss_train: 0.8677 acc_train: 0.7429 acc_val: 0.8000 acc_test: 0.8150 time: 0.0328s
# Epoch: 0397 loss_train: 0.9059 acc_train: 0.7357 acc_val: 0.7980 acc_test: 0.8130 time: 0.0304s
# Epoch: 0398 loss_train: 0.8936 acc_train: 0.7214 acc_val: 0.7960 acc_test: 0.8080 time: 0.0290s
# Epoch: 0399 loss_train: 0.8972 acc_train: 0.6929 acc_val: 0.7840 acc_test: 0.8070 time: 0.0327s
# Epoch: 0400 loss_train: 0.8825 acc_train: 0.6857 acc_val: 0.7800 acc_test: 0.8070 time: 0.0257s
# Optimization Finished!
# Total time elapsed: 13.1244s
# 0.8160000000000001 0.843
# 0.8140000000000001 0.8240000000000001
# 0.812 0.833
# 0.81 0.835
# 0.808 0.842
# 0.806 0.834
# 0.804 0.8150000000000001
# 0.802 0.8210000000000001
# 0.8 0.8150000000000001
# 0.798 0.8130000000000001
