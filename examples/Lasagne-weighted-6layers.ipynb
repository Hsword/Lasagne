# %%
import numpy as np
import pickle as pkl
import networkx as nx
import scipy.sparse as sp
import torch
from scipy.sparse import csgraph
import sys
import time
import argparse
import numpy as np
import torch
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from utils import *
from graphConvolution import *

# %% [markdown]
# ### Load data

# %%
adj, features, labels, idx_train, idx_val, idx_test = load_data(dataset='cora')
# Out:
# [STEP 1]: Upload cora dataset.
# | # of nodes : 2708
# | # of edges : 5278.0
# | # of features : 1433
# | # of clases   : 7
# | # of train set : 140
# | # of val set   : 500
# | # of test set  : 1000

# %%
from torch.autograd import Variable
features, adj, labels = Variable(features), Variable(adj), Variable(labels)
# torch.cuda.manual_seed(72)
features = features.cuda()
adj = adj.cuda()
labels = labels.cuda()
idx_train = idx_train.cuda()
idx_val = idx_val.cuda()
idx_test = idx_test.cuda()

# %% [markdown]
# ### FM-6layers

# %%
class GraphConvolutionFM(Module):
    def __init__(self, in_features, out_features, embedding, bias=True):
        super(GraphConvolutionFM, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.embedding = embedding
        self.weight = Parameter(torch.FloatTensor(in_features, out_features),requires_grad=True)
        self.V = Parameter(torch.randn(out_features, in_features, embedding),requires_grad=True)
        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        self.V.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj,nhid1,nhid2,nhid3,nhid4):
        out_lin = torch.mm(input, self.weight) + self.bias
        # all
        out_1 = torch.matmul(input,self.V).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_2 = torch.matmul(input.pow(2), self.V.pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter1 = 0.5*(out_1 - out_2)
        # x1-xnhid1
        out_3 = torch.matmul(input[:,:nhid1],self.V[:,:nhid1,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_4 = torch.matmul(input[:,:nhid1].pow(2), self.V[:,:nhid1,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter2 = 0.5*(out_3 - out_4)
        # xnhid1-xnhid2
        out_5 = torch.matmul(input[:,nhid1:nhid2],self.V[:,nhid1:nhid2,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_6 = torch.matmul(input[:,nhid1:nhid2].pow(2), self.V[:,nhid1:nhid2,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter3 = 0.5*(out_5 - out_6)
        # xnhid2-xnhid3
        out_7 = torch.matmul(input[:,nhid2:nhid3],self.V[:,nhid2:nhid3,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_8 = torch.matmul(input[:,nhid2:nhid3].pow(2), self.V[:,nhid2:nhid3,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter4 = 0.5*(out_7 - out_8)
        # xnhid3-xnhid4
        out_9 = torch.matmul(input[:,nhid3:nhid4],self.V[:,nhid3:nhid4,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_10 = torch.matmul(input[:,nhid3:nhid4].pow(2), self.V[:,nhid3:nhid4,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter5 = 0.5*(out_9- out_10)
        
        # xnhid4-xnhid5
        out_11 = torch.matmul(input[:,nhid4:],self.V[:,nhid4:,:]).pow(2).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t()
        out_12 = torch.matmul(input[:,nhid4:].pow(2), self.V[:,nhid4:,:].pow(2)).sum(2, keepdim=True).view(self.out_features,input.shape[0]).t() 
        out_inter6 = 0.5*(out_11- out_12)
        
        out_inter = out_inter1 - out_inter2 - out_inter3- out_inter4- out_inter5-out_inter6
        
        output = out_inter + out_lin
        
        output = torch.spmm(adj, output) 
        return output
    

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

# %%
class GCN(nn.Module):
    def __init__(self, nfeat, nhid1,nhid2, nhid3,nhid4,nhid5,nclass, dropout):
        super(GCN, self).__init__()
        self.nhid1 = nhid1
        self.nhid2 = nhid2
        self.nhid3 = nhid3
        self.nhid4 = nhid4
        self.nhid5 = nhid5
        
        self.gc_1 = GraphConvolution(nfeat, nhid1,bias=True)
        self.gc_2 = GraphConvolution(nfeat, nhid2,bias=True)
        self.gc_3 = GraphConvolution(nfeat, nhid3,bias=True)
        self.gc_4 = GraphConvolution(nfeat, nhid4,bias=True)
        
        self.gc1 = GraphConvolution(nfeat, nhid1,bias=True)
        self.gc1_2 = GraphConvolution(nhid1, nhid2,bias=True)
        self.gc1_3 = GraphConvolution(nhid1, nhid3,bias=True)
        self.gc1_4 = GraphConvolution(nhid1, nhid4,bias=True)
        
        
        self.gc2 = GraphConvolution(nhid1, nhid2,bias=True)
        self.gc2_3 = GraphConvolution(nhid2, nhid3,bias=True)
        self.gc2_4 = GraphConvolution(nhid2, nhid4,bias=True)
        
        self.W1 = nn.Parameter(torch.ones(2708, 2),requires_grad=True)
        self.W2 = nn.Parameter(torch.ones(2708, 3),requires_grad=True)
        self.W3 = nn.Parameter(torch.ones(2708, 4),requires_grad=True)
        self.W4 = nn.Parameter(torch.ones(2708, 5),requires_grad=True)
        
        self.gc3 = GraphConvolution(nhid2, nhid3,bias=True)
        self.gc3_4 = GraphConvolution(nhid3, nhid4,bias=True)
        
        self.gc4 = GraphConvolution(nhid3, nhid4,bias=True)
        
        self.gc5 = GraphConvolution(nhid4, nhid5,bias=True)
        
        self.gcFM6 = GraphConvolutionFM(nhid5+nhid4+nhid3+nhid2+nhid1, nclass,embedding=5,bias=True)
        
        self.dropout = dropout

    def forward(self, x, adj):
        x_d = F.dropout(x, self.dropout, training=self.training)
        x_df1 = F.dropout(F.relu(self.gc_1(x_d,adj)), self.dropout, training=self.training)
        x_df2 = F.dropout(F.relu(self.gc_2(x_d,adj)), self.dropout, training=self.training)
        x_df3 = F.dropout(F.relu(self.gc_3(x_d,adj)), self.dropout, training=self.training)
        x_df4 = F.dropout(F.relu(self.gc_4(x_d,adj)), self.dropout, training=self.training)

        x1_d = F.dropout(F.relu(self.gc1(x_d, adj)), training=self.training)
        x1_df2 = F.dropout(F.relu(self.gc1_2(x1_d,adj)), self.dropout, training=self.training)
        x1_df3 = F.dropout(F.relu(self.gc1_3(x1_d,adj)), self.dropout, training=self.training)
        x1_df4 = F.dropout(F.relu(self.gc1_4(x1_d,adj)), self.dropout, training=self.training)
        
        combined1 =  torch.mul(x_df1, self.W1[:,0].view(2708,1)) + torch.mul(x1_d,self.W1[:,1].view(2708,1))
        combined1 = F.dropout(combined1, self.dropout, training=self.training)
        
        x2_d = F.dropout(F.relu(self.gc2(combined1, adj)), self.dropout, training=self.training)
        x2_df3 = F.dropout(F.relu(self.gc2_3(x2_d,adj)), self.dropout, training=self.training)
        x2_df4 = F.dropout(F.relu(self.gc2_4(x2_d,adj)), self.dropout, training=self.training)

        combined2 =  torch.mul(x_df2, self.W2[:,0].view(2708,1)) + torch.mul(x1_df2, self.W2[:,0].view(2708,1))+ torch.mul(x2_d,self.W2[:,2].view(2708,1))
        combined2 = F.dropout(combined2, self.dropout, training=self.training)

        x3_d = F.dropout(F.relu(self.gc3(combined2, adj)), self.dropout, training=self.training)
        x3_df4 = F.dropout(F.relu(self.gc3_4(x3_d,adj)), self.dropout, training=self.training)
        
        combined3 =  torch.mul(x_df3, self.W3[:,0].view(2708,1)) +torch.mul(x1_df3, self.W3[:,1].view(2708,1))+torch.mul(x2_df3, self.W3[:,2].view(2708,1))+ torch.mul(x3_d,self.W3[:,3].view(2708,1)) 
        combined3 = F.dropout(combined3, self.dropout, training=self.training)
        
        x4_d = F.dropout(F.relu(self.gc4(combined3, adj)), self.dropout, training=self.training)
        
        combined4 =  torch.mul(x_df4, self.W4[:,0].view(2708,1)) +torch.mul(x1_df4, self.W4[:,1].view(2708,1))+torch.mul(x2_df4, self.W4[:,2].view(2708,1))+torch.mul(x3_df4, self.W4[:,3].view(2708,1))+torch.mul(x4_d,self.W4[:,4].view(2708,1))  
        combined4 = F.dropout(combined4, self.dropout, training=self.training)
        
        
        x5_d = F.dropout(F.relu(self.gc5(combined4, adj)), self.dropout, training=self.training)
        
        combined5 = torch.cat([x1_d, x2_d, x3_d, x4_d, x5_d], dim=1)
        combined5 = F.dropout(combined5, self.dropout, training=self.training)
        
        x6 = self.gcFM6(combined5,adj,self.nhid1,self.nhid2+self.nhid1,self.nhid3+self.nhid2+self.nhid1,self.nhid4+self.nhid3+self.nhid2+self.nhid1) 
        return F.log_softmax(x6, dim=1)

# %%
def train(epoch, model,record):
    t = time.time()
    model.train()
    optimizer.zero_grad()
    output = model(features, adj)
    loss_train = F.cross_entropy(output[idx_train], labels[idx_train]) 
    acc_train = accuracy(output[idx_train], labels[idx_train])
    loss_train.backward()
    optimizer.step()
    model.eval()
    output = model(features, adj)

    loss_val = F.cross_entropy(output[idx_val], labels[idx_val])
    acc_val = accuracy(output[idx_val], labels[idx_val])
    
    loss_test = F.cross_entropy(output[idx_test], labels[idx_test])
    acc_test = accuracy(output[idx_test], labels[idx_test])
    print('Epoch: {:04d}'.format(epoch+1),
          'loss_train: {:.4f}'.format(loss_train.item()),
          'acc_train: {:.4f}'.format(acc_train.item()),
          'acc_val: {:.4f}'.format(acc_val.item()),
          'acc_test: {:.4f}'.format(acc_test.item()),
          'time: {:.4f}s'.format(time.time() - t))
    record[acc_val.item()] = acc_test.item()

# %%
model = GCN(nfeat=features.shape[1],
                nhid1=32,
                nhid2=32,
                nhid3=32,
                nhid4=32,
                nhid5=32,
                nclass=labels.max().item() + 1,
                dropout=0.8)
model.cuda()
optimizer = optim.Adam(model.parameters(),
                       lr=0.02, weight_decay=5e-4)
t_total = time.time()
record = {}
for epoch in range(400):  
    train(epoch,model,record)
print("Optimization Finished!")
print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
bit_list = sorted(record.keys())
bit_list.reverse()
for key in bit_list[:10]:
    value = record[key]
    print(key,value)
# Out:
# Epoch: 0001 loss_train: 11.5620 acc_train: 0.1071 acc_val: 0.0760 acc_test: 0.0930 time: 0.0511s
# Epoch: 0002 loss_train: 3.5902 acc_train: 0.1429 acc_val: 0.0760 acc_test: 0.0920 time: 0.0384s
# Epoch: 0003 loss_train: 2.5083 acc_train: 0.1143 acc_val: 0.0860 acc_test: 0.1050 time: 0.0377s
# Epoch: 0004 loss_train: 2.3134 acc_train: 0.1429 acc_val: 0.1860 acc_test: 0.2030 time: 0.0350s
# Epoch: 0005 loss_train: 2.2924 acc_train: 0.1143 acc_val: 0.2500 acc_test: 0.2450 time: 0.0386s
# Epoch: 0006 loss_train: 2.1104 acc_train: 0.1357 acc_val: 0.0880 acc_test: 0.1130 time: 0.0395s
# Epoch: 0007 loss_train: 2.0289 acc_train: 0.1500 acc_val: 0.1560 acc_test: 0.1520 time: 0.0399s
# Epoch: 0008 loss_train: 1.9527 acc_train: 0.1357 acc_val: 0.1620 acc_test: 0.1550 time: 0.0331s
# Epoch: 0009 loss_train: 2.0664 acc_train: 0.1357 acc_val: 0.1620 acc_test: 0.1510 time: 0.0424s
# Epoch: 0010 loss_train: 1.9618 acc_train: 0.1643 acc_val: 0.1620 acc_test: 0.1490 time: 0.0366s
# Epoch: 0011 loss_train: 1.9525 acc_train: 0.1857 acc_val: 0.1620 acc_test: 0.1490 time: 0.0339s
# Epoch: 0012 loss_train: 1.9676 acc_train: 0.1643 acc_val: 0.1620 acc_test: 0.1490 time: 0.0381s
# Epoch: 0013 loss_train: 1.9568 acc_train: 0.1500 acc_val: 0.1620 acc_test: 0.1490 time: 0.0374s
# Epoch: 0014 loss_train: 1.9740 acc_train: 0.1214 acc_val: 0.1620 acc_test: 0.1490 time: 0.0338s
# Epoch: 0015 loss_train: 1.9749 acc_train: 0.1143 acc_val: 0.1620 acc_test: 0.1490 time: 0.0337s
# Epoch: 0016 loss_train: 1.9269 acc_train: 0.1571 acc_val: 0.1620 acc_test: 0.1490 time: 0.0380s
# Epoch: 0017 loss_train: 1.9626 acc_train: 0.1786 acc_val: 0.1620 acc_test: 0.1490 time: 0.0348s
# Epoch: 0018 loss_train: 1.9443 acc_train: 0.1643 acc_val: 0.1620 acc_test: 0.1490 time: 0.0341s
# Epoch: 0019 loss_train: 1.9569 acc_train: 0.1857 acc_val: 0.1620 acc_test: 0.1500 time: 0.0380s
# Epoch: 0020 loss_train: 2.0987 acc_train: 0.1857 acc_val: 0.1620 acc_test: 0.1500 time: 0.0332s
# Epoch: 0021 loss_train: 1.9607 acc_train: 0.2071 acc_val: 0.1660 acc_test: 0.1500 time: 0.0329s
# Epoch: 0022 loss_train: 1.9470 acc_train: 0.1929 acc_val: 0.1700 acc_test: 0.1570 time: 0.0390s
# Epoch: 0023 loss_train: 1.9433 acc_train: 0.2000 acc_val: 0.1860 acc_test: 0.1820 time: 0.0367s
# Epoch: 0024 loss_train: 1.9601 acc_train: 0.1286 acc_val: 0.2080 acc_test: 0.2150 time: 0.0349s
# Epoch: 0025 loss_train: 1.9370 acc_train: 0.2000 acc_val: 0.2600 acc_test: 0.2650 time: 0.0350s
# Epoch: 0026 loss_train: 1.9375 acc_train: 0.1714 acc_val: 0.3200 acc_test: 0.3250 time: 0.0348s
# Epoch: 0027 loss_train: 1.9053 acc_train: 0.2500 acc_val: 0.3080 acc_test: 0.3110 time: 0.0366s
# Epoch: 0028 loss_train: 1.9650 acc_train: 0.2286 acc_val: 0.2740 acc_test: 0.2980 time: 0.0378s
# Epoch: 0029 loss_train: 1.9121 acc_train: 0.1857 acc_val: 0.2600 acc_test: 0.2920 time: 0.0368s
# Epoch: 0030 loss_train: 1.9219 acc_train: 0.2571 acc_val: 0.2560 acc_test: 0.2860 time: 0.0341s
# Epoch: 0031 loss_train: 1.8988 acc_train: 0.2071 acc_val: 0.2580 acc_test: 0.2840 time: 0.0349s
# Epoch: 0032 loss_train: 1.9139 acc_train: 0.2143 acc_val: 0.2660 acc_test: 0.2920 time: 0.0347s
# Epoch: 0033 loss_train: 1.8819 acc_train: 0.2571 acc_val: 0.2840 acc_test: 0.3140 time: 0.0367s
# Epoch: 0034 loss_train: 1.9106 acc_train: 0.2429 acc_val: 0.3180 acc_test: 0.3360 time: 0.0374s
# Epoch: 0035 loss_train: 1.8850 acc_train: 0.2071 acc_val: 0.3340 acc_test: 0.3650 time: 0.0376s
# Epoch: 0036 loss_train: 1.8872 acc_train: 0.2929 acc_val: 0.3660 acc_test: 0.3920 time: 0.0363s
# Epoch: 0037 loss_train: 1.8755 acc_train: 0.2071 acc_val: 0.3820 acc_test: 0.4020 time: 0.0366s
# Epoch: 0038 loss_train: 1.8710 acc_train: 0.2286 acc_val: 0.4120 acc_test: 0.4210 time: 0.0310s
# Epoch: 0039 loss_train: 1.8883 acc_train: 0.2429 acc_val: 0.4420 acc_test: 0.4600 time: 0.0343s
# Epoch: 0040 loss_train: 1.8421 acc_train: 0.3286 acc_val: 0.4740 acc_test: 0.4800 time: 0.0331s
# Epoch: 0041 loss_train: 1.8435 acc_train: 0.3429 acc_val: 0.4760 acc_test: 0.4860 time: 0.0330s
# Epoch: 0042 loss_train: 1.8384 acc_train: 0.2643 acc_val: 0.4440 acc_test: 0.4510 time: 0.0359s
# Epoch: 0043 loss_train: 1.8632 acc_train: 0.2500 acc_val: 0.3900 acc_test: 0.4060 time: 0.0374s
# Epoch: 0044 loss_train: 1.8927 acc_train: 0.2643 acc_val: 0.3600 acc_test: 0.3740 time: 0.0310s
# Epoch: 0045 loss_train: 1.8394 acc_train: 0.3000 acc_val: 0.3500 acc_test: 0.3670 time: 0.0330s
# Epoch: 0046 loss_train: 1.8491 acc_train: 0.2571 acc_val: 0.3660 acc_test: 0.3660 time: 0.0330s
# Epoch: 0047 loss_train: 1.7966 acc_train: 0.3643 acc_val: 0.3600 acc_test: 0.3720 time: 0.0357s
# Epoch: 0048 loss_train: 1.8271 acc_train: 0.3143 acc_val: 0.3720 acc_test: 0.3850 time: 0.0360s
# Epoch: 0049 loss_train: 1.8302 acc_train: 0.3143 acc_val: 0.3940 acc_test: 0.4030 time: 0.0341s
# Epoch: 0050 loss_train: 1.7898 acc_train: 0.3000 acc_val: 0.4360 acc_test: 0.4300 time: 0.0333s
# Epoch: 0051 loss_train: 1.7912 acc_train: 0.3286 acc_val: 0.4820 acc_test: 0.4770 time: 0.0331s
# Epoch: 0052 loss_train: 1.8063 acc_train: 0.3286 acc_val: 0.5280 acc_test: 0.4990 time: 0.0339s
# Epoch: 0053 loss_train: 1.7800 acc_train: 0.2786 acc_val: 0.5520 acc_test: 0.5490 time: 0.0358s
# Epoch: 0054 loss_train: 1.7628 acc_train: 0.3571 acc_val: 0.5780 acc_test: 0.5790 time: 0.0362s
# Epoch: 0055 loss_train: 1.7297 acc_train: 0.3714 acc_val: 0.6240 acc_test: 0.6190 time: 0.0340s
# Epoch: 0056 loss_train: 1.7497 acc_train: 0.2857 acc_val: 0.6600 acc_test: 0.6580 time: 0.0332s
# Epoch: 0057 loss_train: 1.7468 acc_train: 0.3786 acc_val: 0.6780 acc_test: 0.6880 time: 0.0337s
# Epoch: 0058 loss_train: 1.7276 acc_train: 0.3643 acc_val: 0.6900 acc_test: 0.7120 time: 0.0337s
# Epoch: 0059 loss_train: 1.7309 acc_train: 0.3714 acc_val: 0.7060 acc_test: 0.7260 time: 0.0336s
# Epoch: 0060 loss_train: 1.7185 acc_train: 0.3500 acc_val: 0.7120 acc_test: 0.7240 time: 0.0331s
# Epoch: 0061 loss_train: 1.7675 acc_train: 0.4143 acc_val: 0.6980 acc_test: 0.7030 time: 0.0352s
# Epoch: 0062 loss_train: 1.6967 acc_train: 0.3500 acc_val: 0.6860 acc_test: 0.6910 time: 0.0334s
# Epoch: 0063 loss_train: 1.6562 acc_train: 0.4071 acc_val: 0.6840 acc_test: 0.6800 time: 0.0357s
# Epoch: 0064 loss_train: 1.7087 acc_train: 0.3786 acc_val: 0.6800 acc_test: 0.6840 time: 0.0349s
# Epoch: 0065 loss_train: 1.7322 acc_train: 0.3357 acc_val: 0.6880 acc_test: 0.7010 time: 0.0329s
# Epoch: 0066 loss_train: 1.6068 acc_train: 0.4071 acc_val: 0.6980 acc_test: 0.7190 time: 0.0333s
# Epoch: 0067 loss_train: 1.6752 acc_train: 0.3357 acc_val: 0.7120 acc_test: 0.7310 time: 0.0361s
# Epoch: 0068 loss_train: 1.6324 acc_train: 0.3500 acc_val: 0.7500 acc_test: 0.7490 time: 0.0384s
# Epoch: 0069 loss_train: 1.7115 acc_train: 0.3429 acc_val: 0.7600 acc_test: 0.7680 time: 0.0332s
# Epoch: 0070 loss_train: 1.6445 acc_train: 0.4571 acc_val: 0.7600 acc_test: 0.7740 time: 0.0334s
# Epoch: 0071 loss_train: 1.6238 acc_train: 0.4357 acc_val: 0.7700 acc_test: 0.7800 time: 0.0357s
# Epoch: 0072 loss_train: 1.6440 acc_train: 0.3643 acc_val: 0.7680 acc_test: 0.7770 time: 0.0358s
# Epoch: 0073 loss_train: 1.6284 acc_train: 0.4286 acc_val: 0.7720 acc_test: 0.7750 time: 0.0336s
# Epoch: 0074 loss_train: 1.6337 acc_train: 0.4571 acc_val: 0.7680 acc_test: 0.7690 time: 0.0337s
# Epoch: 0075 loss_train: 1.6072 acc_train: 0.4143 acc_val: 0.7720 acc_test: 0.7710 time: 0.0357s
# Epoch: 0076 loss_train: 1.6228 acc_train: 0.4214 acc_val: 0.7740 acc_test: 0.7700 time: 0.0346s
# Epoch: 0077 loss_train: 1.5372 acc_train: 0.4214 acc_val: 0.7580 acc_test: 0.7710 time: 0.0355s
# Epoch: 0078 loss_train: 1.5937 acc_train: 0.4714 acc_val: 0.7480 acc_test: 0.7670 time: 0.0364s
# Epoch: 0079 loss_train: 1.4985 acc_train: 0.5000 acc_val: 0.7480 acc_test: 0.7690 time: 0.0340s
# Epoch: 0080 loss_train: 1.6207 acc_train: 0.4000 acc_val: 0.7460 acc_test: 0.7650 time: 0.0336s
# Epoch: 0081 loss_train: 1.4765 acc_train: 0.5214 acc_val: 0.7620 acc_test: 0.7740 time: 0.0336s
# Epoch: 0082 loss_train: 1.6078 acc_train: 0.4357 acc_val: 0.7720 acc_test: 0.7750 time: 0.0357s
# Epoch: 0083 loss_train: 1.5683 acc_train: 0.4714 acc_val: 0.7660 acc_test: 0.7710 time: 0.0386s
# Epoch: 0084 loss_train: 1.5237 acc_train: 0.4571 acc_val: 0.7660 acc_test: 0.7760 time: 0.0334s
# Epoch: 0085 loss_train: 1.4373 acc_train: 0.4786 acc_val: 0.7540 acc_test: 0.7780 time: 0.0336s
# Epoch: 0086 loss_train: 1.5746 acc_train: 0.4143 acc_val: 0.7500 acc_test: 0.7680 time: 0.0334s
# Epoch: 0087 loss_train: 1.4582 acc_train: 0.5429 acc_val: 0.7440 acc_test: 0.7630 time: 0.0359s
# Epoch: 0088 loss_train: 1.5959 acc_train: 0.3786 acc_val: 0.7480 acc_test: 0.7660 time: 0.0345s
# Epoch: 0089 loss_train: 1.5332 acc_train: 0.4071 acc_val: 0.7440 acc_test: 0.7690 time: 0.0356s
# Epoch: 0090 loss_train: 1.4921 acc_train: 0.5000 acc_val: 0.7540 acc_test: 0.7700 time: 0.0361s
# Epoch: 0091 loss_train: 1.4228 acc_train: 0.4786 acc_val: 0.7560 acc_test: 0.7720 time: 0.0336s
# Epoch: 0092 loss_train: 1.5333 acc_train: 0.4286 acc_val: 0.7700 acc_test: 0.7830 time: 0.0329s
# Epoch: 0093 loss_train: 1.3958 acc_train: 0.5357 acc_val: 0.7720 acc_test: 0.7900 time: 0.0358s
# Epoch: 0094 loss_train: 1.4330 acc_train: 0.4714 acc_val: 0.7720 acc_test: 0.7970 time: 0.0361s
# Epoch: 0095 loss_train: 1.4314 acc_train: 0.4786 acc_val: 0.7720 acc_test: 0.8070 time: 0.0330s
# Epoch: 0096 loss_train: 1.4784 acc_train: 0.5000 acc_val: 0.7820 acc_test: 0.8090 time: 0.0331s
# Epoch: 0097 loss_train: 1.4382 acc_train: 0.5000 acc_val: 0.7920 acc_test: 0.8130 time: 0.0343s
# Epoch: 0098 loss_train: 1.4187 acc_train: 0.5143 acc_val: 0.7940 acc_test: 0.8150 time: 0.0364s
# Epoch: 0099 loss_train: 1.4576 acc_train: 0.4786 acc_val: 0.7880 acc_test: 0.8130 time: 0.0340s
# Epoch: 0100 loss_train: 1.3723 acc_train: 0.4786 acc_val: 0.7840 acc_test: 0.8020 time: 0.0336s
# Epoch: 0101 loss_train: 1.4339 acc_train: 0.4500 acc_val: 0.7840 acc_test: 0.7990 time: 0.0332s
# Epoch: 0102 loss_train: 1.4814 acc_train: 0.4214 acc_val: 0.7800 acc_test: 0.7960 time: 0.0338s
# Epoch: 0103 loss_train: 1.4311 acc_train: 0.5214 acc_val: 0.7780 acc_test: 0.7960 time: 0.0367s
# Epoch: 0104 loss_train: 1.3425 acc_train: 0.5714 acc_val: 0.7660 acc_test: 0.7920 time: 0.0344s
# Epoch: 0105 loss_train: 1.4263 acc_train: 0.4429 acc_val: 0.7620 acc_test: 0.7910 time: 0.0336s
# Epoch: 0106 loss_train: 1.4231 acc_train: 0.4714 acc_val: 0.7640 acc_test: 0.7870 time: 0.0336s
# Epoch: 0107 loss_train: 1.4317 acc_train: 0.4714 acc_val: 0.7640 acc_test: 0.7900 time: 0.0329s
# Epoch: 0108 loss_train: 1.2930 acc_train: 0.6214 acc_val: 0.7680 acc_test: 0.7900 time: 0.0355s
# Epoch: 0109 loss_train: 1.4349 acc_train: 0.4714 acc_val: 0.7700 acc_test: 0.7940 time: 0.0388s
# Epoch: 0110 loss_train: 1.4608 acc_train: 0.4643 acc_val: 0.7720 acc_test: 0.7930 time: 0.0329s
# Epoch: 0111 loss_train: 1.3536 acc_train: 0.5000 acc_val: 0.7740 acc_test: 0.7920 time: 0.0353s
# Epoch: 0112 loss_train: 1.2041 acc_train: 0.5714 acc_val: 0.7720 acc_test: 0.7930 time: 0.0329s
# Epoch: 0113 loss_train: 1.3100 acc_train: 0.5286 acc_val: 0.7840 acc_test: 0.8010 time: 0.0358s
# Epoch: 0114 loss_train: 1.3317 acc_train: 0.5071 acc_val: 0.7860 acc_test: 0.8020 time: 0.0360s
# Epoch: 0115 loss_train: 1.3623 acc_train: 0.5357 acc_val: 0.7880 acc_test: 0.8100 time: 0.0338s
# Epoch: 0116 loss_train: 1.3051 acc_train: 0.5286 acc_val: 0.7960 acc_test: 0.8160 time: 0.0336s
# Epoch: 0117 loss_train: 1.2428 acc_train: 0.5929 acc_val: 0.7940 acc_test: 0.8220 time: 0.0360s
# Epoch: 0118 loss_train: 1.4228 acc_train: 0.4786 acc_val: 0.7960 acc_test: 0.8220 time: 0.0345s
# Epoch: 0119 loss_train: 1.3292 acc_train: 0.4643 acc_val: 0.8000 acc_test: 0.8270 time: 0.0335s
# Epoch: 0120 loss_train: 1.2509 acc_train: 0.5500 acc_val: 0.8020 acc_test: 0.8330 time: 0.0359s
# Epoch: 0121 loss_train: 1.4074 acc_train: 0.4714 acc_val: 0.8060 acc_test: 0.8360 time: 0.0397s
# Epoch: 0122 loss_train: 1.3690 acc_train: 0.5143 acc_val: 0.8060 acc_test: 0.8370 time: 0.0332s
# Epoch: 0123 loss_train: 1.3619 acc_train: 0.5000 acc_val: 0.8020 acc_test: 0.8350 time: 0.0334s
# Epoch: 0124 loss_train: 1.2873 acc_train: 0.5714 acc_val: 0.8020 acc_test: 0.8390 time: 0.0328s
# Epoch: 0125 loss_train: 1.3758 acc_train: 0.4857 acc_val: 0.8020 acc_test: 0.8400 time: 0.0356s
# Epoch: 0126 loss_train: 1.2750 acc_train: 0.5786 acc_val: 0.8000 acc_test: 0.8350 time: 0.0360s
# Epoch: 0127 loss_train: 1.3264 acc_train: 0.5143 acc_val: 0.7980 acc_test: 0.8340 time: 0.0331s
# Epoch: 0128 loss_train: 1.2158 acc_train: 0.5786 acc_val: 0.7920 acc_test: 0.8300 time: 0.0355s
# Epoch: 0129 loss_train: 1.2980 acc_train: 0.5214 acc_val: 0.7880 acc_test: 0.8250 time: 0.0346s
# Epoch: 0130 loss_train: 1.2696 acc_train: 0.5714 acc_val: 0.7820 acc_test: 0.8210 time: 0.0356s
# Epoch: 0131 loss_train: 1.2726 acc_train: 0.5571 acc_val: 0.7860 acc_test: 0.8170 time: 0.0357s
# Epoch: 0132 loss_train: 1.2200 acc_train: 0.5857 acc_val: 0.7960 acc_test: 0.8150 time: 0.0335s
# Epoch: 0133 loss_train: 1.3090 acc_train: 0.5714 acc_val: 0.7940 acc_test: 0.8170 time: 0.0359s
# Epoch: 0134 loss_train: 1.2975 acc_train: 0.5214 acc_val: 0.7960 acc_test: 0.8150 time: 0.0365s
# Epoch: 0135 loss_train: 1.2737 acc_train: 0.5500 acc_val: 0.8000 acc_test: 0.8130 time: 0.0332s
# Epoch: 0136 loss_train: 1.3452 acc_train: 0.5071 acc_val: 0.8000 acc_test: 0.8140 time: 0.0335s
# Epoch: 0137 loss_train: 1.2576 acc_train: 0.5286 acc_val: 0.8020 acc_test: 0.8140 time: 0.0331s
# Epoch: 0138 loss_train: 1.2498 acc_train: 0.5714 acc_val: 0.8000 acc_test: 0.8120 time: 0.0330s
# Epoch: 0139 loss_train: 1.2381 acc_train: 0.5786 acc_val: 0.7880 acc_test: 0.8150 time: 0.0364s
# Epoch: 0140 loss_train: 1.2390 acc_train: 0.5643 acc_val: 0.7840 acc_test: 0.8100 time: 0.0359s
# Epoch: 0141 loss_train: 1.3242 acc_train: 0.4429 acc_val: 0.7820 acc_test: 0.8090 time: 0.0336s
# Epoch: 0142 loss_train: 1.1777 acc_train: 0.5643 acc_val: 0.7760 acc_test: 0.8050 time: 0.0330s
# Epoch: 0143 loss_train: 1.1893 acc_train: 0.6000 acc_val: 0.7720 acc_test: 0.8080 time: 0.0335s
# Epoch: 0144 loss_train: 1.3523 acc_train: 0.5357 acc_val: 0.7700 acc_test: 0.8040 time: 0.0330s
# Epoch: 0145 loss_train: 1.3205 acc_train: 0.5214 acc_val: 0.7740 acc_test: 0.8030 time: 0.0364s
# Epoch: 0146 loss_train: 1.2556 acc_train: 0.5786 acc_val: 0.7800 acc_test: 0.8080 time: 0.0356s
# Epoch: 0147 loss_train: 1.2561 acc_train: 0.5429 acc_val: 0.7840 acc_test: 0.8060 time: 0.0331s
# Epoch: 0148 loss_train: 1.2521 acc_train: 0.5214 acc_val: 0.7820 acc_test: 0.8130 time: 0.0331s
# Epoch: 0149 loss_train: 1.2427 acc_train: 0.5429 acc_val: 0.7800 acc_test: 0.8190 time: 0.0357s
# Epoch: 0150 loss_train: 1.2566 acc_train: 0.5500 acc_val: 0.7900 acc_test: 0.8220 time: 0.0362s
# Epoch: 0151 loss_train: 1.2867 acc_train: 0.5500 acc_val: 0.7920 acc_test: 0.8230 time: 0.0337s
# Epoch: 0152 loss_train: 1.2688 acc_train: 0.5714 acc_val: 0.7980 acc_test: 0.8280 time: 0.0328s
# Epoch: 0153 loss_train: 1.2682 acc_train: 0.5571 acc_val: 0.7960 acc_test: 0.8300 time: 0.0357s
# Epoch: 0154 loss_train: 1.2724 acc_train: 0.5357 acc_val: 0.7960 acc_test: 0.8310 time: 0.0384s
# Epoch: 0155 loss_train: 1.2360 acc_train: 0.5571 acc_val: 0.7940 acc_test: 0.8310 time: 0.0335s
# Epoch: 0156 loss_train: 1.2213 acc_train: 0.5786 acc_val: 0.7940 acc_test: 0.8360 time: 0.0329s
# Epoch: 0157 loss_train: 1.2842 acc_train: 0.5786 acc_val: 0.7920 acc_test: 0.8360 time: 0.0359s
# Epoch: 0158 loss_train: 1.1442 acc_train: 0.6000 acc_val: 0.7920 acc_test: 0.8410 time: 0.0360s
# Epoch: 0159 loss_train: 1.1340 acc_train: 0.5643 acc_val: 0.7920 acc_test: 0.8430 time: 0.0333s
# Epoch: 0160 loss_train: 1.1180 acc_train: 0.5857 acc_val: 0.7960 acc_test: 0.8470 time: 0.0333s
# Epoch: 0161 loss_train: 1.2267 acc_train: 0.5286 acc_val: 0.7960 acc_test: 0.8470 time: 0.0360s
# Epoch: 0162 loss_train: 1.2128 acc_train: 0.5571 acc_val: 0.7860 acc_test: 0.8360 time: 0.0383s
# Epoch: 0163 loss_train: 1.0893 acc_train: 0.6357 acc_val: 0.7880 acc_test: 0.8350 time: 0.0334s
# Epoch: 0164 loss_train: 1.3411 acc_train: 0.4714 acc_val: 0.7820 acc_test: 0.8320 time: 0.0328s
# Epoch: 0165 loss_train: 1.1330 acc_train: 0.5857 acc_val: 0.7760 acc_test: 0.8280 time: 0.0358s
# Epoch: 0166 loss_train: 1.1666 acc_train: 0.5857 acc_val: 0.7740 acc_test: 0.8190 time: 0.0363s
# Epoch: 0167 loss_train: 1.1974 acc_train: 0.6071 acc_val: 0.7800 acc_test: 0.8140 time: 0.0328s
# Epoch: 0168 loss_train: 1.1283 acc_train: 0.5857 acc_val: 0.7840 acc_test: 0.8130 time: 0.0358s
# Epoch: 0169 loss_train: 1.1255 acc_train: 0.6357 acc_val: 0.7820 acc_test: 0.8160 time: 0.0365s
# Epoch: 0170 loss_train: 1.1247 acc_train: 0.6357 acc_val: 0.7800 acc_test: 0.8180 time: 0.0335s
# Epoch: 0171 loss_train: 1.1495 acc_train: 0.5714 acc_val: 0.7860 acc_test: 0.8150 time: 0.0328s
# Epoch: 0172 loss_train: 1.1385 acc_train: 0.6286 acc_val: 0.7780 acc_test: 0.8060 time: 0.0357s
# Epoch: 0173 loss_train: 1.1850 acc_train: 0.6143 acc_val: 0.7760 acc_test: 0.8070 time: 0.0387s
# Epoch: 0174 loss_train: 1.2369 acc_train: 0.5143 acc_val: 0.7760 acc_test: 0.8010 time: 0.0327s
# Epoch: 0175 loss_train: 1.2568 acc_train: 0.5500 acc_val: 0.7800 acc_test: 0.7990 time: 0.0330s
# Epoch: 0176 loss_train: 1.2346 acc_train: 0.5429 acc_val: 0.7800 acc_test: 0.8000 time: 0.0356s
# Epoch: 0177 loss_train: 1.2849 acc_train: 0.5571 acc_val: 0.7840 acc_test: 0.8080 time: 0.0350s
# Epoch: 0178 loss_train: 1.0143 acc_train: 0.6286 acc_val: 0.7900 acc_test: 0.8230 time: 0.0329s
# Epoch: 0179 loss_train: 1.2918 acc_train: 0.5286 acc_val: 0.7900 acc_test: 0.8280 time: 0.0329s
# Epoch: 0180 loss_train: 1.2775 acc_train: 0.5286 acc_val: 0.7900 acc_test: 0.8330 time: 0.0357s
# Epoch: 0181 loss_train: 1.1900 acc_train: 0.5786 acc_val: 0.7920 acc_test: 0.8340 time: 0.0349s
# Epoch: 0182 loss_train: 1.1816 acc_train: 0.5643 acc_val: 0.7940 acc_test: 0.8370 time: 0.0335s
# Epoch: 0183 loss_train: 1.1129 acc_train: 0.6714 acc_val: 0.7920 acc_test: 0.8400 time: 0.0332s
# Epoch: 0184 loss_train: 1.0467 acc_train: 0.6571 acc_val: 0.7920 acc_test: 0.8390 time: 0.0358s
# Epoch: 0185 loss_train: 1.2245 acc_train: 0.5857 acc_val: 0.7920 acc_test: 0.8440 time: 0.0368s
# Epoch: 0186 loss_train: 1.1942 acc_train: 0.5214 acc_val: 0.7860 acc_test: 0.8430 time: 0.0330s
# Epoch: 0187 loss_train: 1.2803 acc_train: 0.5500 acc_val: 0.7880 acc_test: 0.8370 time: 0.0327s
# Epoch: 0188 loss_train: 1.1339 acc_train: 0.5929 acc_val: 0.7860 acc_test: 0.8260 time: 0.0331s
# Epoch: 0189 loss_train: 1.0908 acc_train: 0.6571 acc_val: 0.7760 acc_test: 0.8240 time: 0.0358s
# Epoch: 0190 loss_train: 1.0828 acc_train: 0.5857 acc_val: 0.7780 acc_test: 0.8220 time: 0.0345s
# Epoch: 0191 loss_train: 1.1642 acc_train: 0.5857 acc_val: 0.7860 acc_test: 0.8180 time: 0.0328s
# Epoch: 0192 loss_train: 1.1989 acc_train: 0.5857 acc_val: 0.7900 acc_test: 0.8140 time: 0.0356s
# Epoch: 0193 loss_train: 1.2420 acc_train: 0.5929 acc_val: 0.7860 acc_test: 0.8120 time: 0.0384s
# Epoch: 0194 loss_train: 1.1619 acc_train: 0.5429 acc_val: 0.7860 acc_test: 0.8110 time: 0.0330s
# Epoch: 0195 loss_train: 1.1204 acc_train: 0.6429 acc_val: 0.7840 acc_test: 0.8080 time: 0.0332s
# Epoch: 0196 loss_train: 1.0928 acc_train: 0.6143 acc_val: 0.7820 acc_test: 0.8080 time: 0.0357s
# Epoch: 0197 loss_train: 1.1353 acc_train: 0.6071 acc_val: 0.7700 acc_test: 0.8080 time: 0.0359s
# Epoch: 0198 loss_train: 1.1044 acc_train: 0.6214 acc_val: 0.7700 acc_test: 0.8050 time: 0.0333s
# Epoch: 0199 loss_train: 1.1596 acc_train: 0.5929 acc_val: 0.7760 acc_test: 0.8060 time: 0.0358s
# Epoch: 0200 loss_train: 1.0859 acc_train: 0.6786 acc_val: 0.7760 acc_test: 0.8050 time: 0.0362s
# Epoch: 0201 loss_train: 1.1856 acc_train: 0.5286 acc_val: 0.7780 acc_test: 0.8090 time: 0.0327s
# Epoch: 0202 loss_train: 1.0231 acc_train: 0.6786 acc_val: 0.7800 acc_test: 0.8060 time: 0.0333s
# Epoch: 0203 loss_train: 1.0926 acc_train: 0.6000 acc_val: 0.7840 acc_test: 0.8090 time: 0.0357s
# Epoch: 0204 loss_train: 1.0699 acc_train: 0.6714 acc_val: 0.7760 acc_test: 0.8100 time: 0.0353s
# Epoch: 0205 loss_train: 1.2878 acc_train: 0.5500 acc_val: 0.7760 acc_test: 0.8110 time: 0.0347s
# Epoch: 0206 loss_train: 1.0838 acc_train: 0.6500 acc_val: 0.7820 acc_test: 0.8100 time: 0.0336s
# Epoch: 0207 loss_train: 1.1448 acc_train: 0.5571 acc_val: 0.7860 acc_test: 0.8150 time: 0.0335s
# Epoch: 0208 loss_train: 1.0654 acc_train: 0.6643 acc_val: 0.8000 acc_test: 0.8150 time: 0.0338s
# Epoch: 0209 loss_train: 1.0649 acc_train: 0.6500 acc_val: 0.7980 acc_test: 0.8190 time: 0.0339s
# Epoch: 0210 loss_train: 1.0240 acc_train: 0.6500 acc_val: 0.7980 acc_test: 0.8180 time: 0.0359s
# Epoch: 0211 loss_train: 1.1155 acc_train: 0.6214 acc_val: 0.7980 acc_test: 0.8200 time: 0.0367s
# Epoch: 0212 loss_train: 1.1887 acc_train: 0.6071 acc_val: 0.7980 acc_test: 0.8200 time: 0.0331s
# Epoch: 0213 loss_train: 1.0806 acc_train: 0.6571 acc_val: 0.7900 acc_test: 0.8170 time: 0.0331s
# Epoch: 0214 loss_train: 1.0828 acc_train: 0.5786 acc_val: 0.7920 acc_test: 0.8200 time: 0.0336s
# Epoch: 0215 loss_train: 0.9490 acc_train: 0.6500 acc_val: 0.7860 acc_test: 0.8170 time: 0.0330s
# Epoch: 0216 loss_train: 1.0182 acc_train: 0.6643 acc_val: 0.7800 acc_test: 0.8160 time: 0.0358s
# Epoch: 0217 loss_train: 0.9687 acc_train: 0.6643 acc_val: 0.7800 acc_test: 0.8110 time: 0.0369s
# Epoch: 0218 loss_train: 1.0134 acc_train: 0.7000 acc_val: 0.7760 acc_test: 0.8070 time: 0.0324s
# Epoch: 0219 loss_train: 1.0598 acc_train: 0.6571 acc_val: 0.7740 acc_test: 0.7940 time: 0.0336s
# Epoch: 0220 loss_train: 0.9793 acc_train: 0.6286 acc_val: 0.7660 acc_test: 0.7900 time: 0.0331s
# Epoch: 0221 loss_train: 0.9726 acc_train: 0.6857 acc_val: 0.7580 acc_test: 0.7830 time: 0.0332s
# Epoch: 0222 loss_train: 1.0295 acc_train: 0.6714 acc_val: 0.7540 acc_test: 0.7790 time: 0.0338s
# Epoch: 0223 loss_train: 1.0084 acc_train: 0.6714 acc_val: 0.7560 acc_test: 0.7710 time: 0.0365s
# Epoch: 0224 loss_train: 0.9789 acc_train: 0.7143 acc_val: 0.7600 acc_test: 0.7690 time: 0.0374s
# Epoch: 0225 loss_train: 0.8916 acc_train: 0.7429 acc_val: 0.7640 acc_test: 0.7730 time: 0.0320s
# Epoch: 0226 loss_train: 0.9350 acc_train: 0.6643 acc_val: 0.7600 acc_test: 0.7760 time: 0.0330s
# Epoch: 0227 loss_train: 1.0072 acc_train: 0.6571 acc_val: 0.7620 acc_test: 0.7830 time: 0.0335s
# Epoch: 0228 loss_train: 1.1154 acc_train: 0.6500 acc_val: 0.7600 acc_test: 0.7800 time: 0.0331s
# Epoch: 0229 loss_train: 0.8777 acc_train: 0.6857 acc_val: 0.7560 acc_test: 0.7850 time: 0.0364s
# Epoch: 0230 loss_train: 0.8648 acc_train: 0.7357 acc_val: 0.7500 acc_test: 0.7860 time: 0.0346s
# Epoch: 0231 loss_train: 1.0103 acc_train: 0.6571 acc_val: 0.7520 acc_test: 0.7860 time: 0.0336s
# Epoch: 0232 loss_train: 0.9606 acc_train: 0.6357 acc_val: 0.7440 acc_test: 0.7760 time: 0.0327s
# Epoch: 0233 loss_train: 0.8952 acc_train: 0.7286 acc_val: 0.7380 acc_test: 0.7720 time: 0.0356s
# Epoch: 0234 loss_train: 0.9041 acc_train: 0.6714 acc_val: 0.7320 acc_test: 0.7560 time: 0.0384s
# Epoch: 0235 loss_train: 0.9139 acc_train: 0.7071 acc_val: 0.7180 acc_test: 0.7440 time: 0.0320s
# Epoch: 0236 loss_train: 0.8996 acc_train: 0.7000 acc_val: 0.7100 acc_test: 0.7320 time: 0.0356s
# Epoch: 0237 loss_train: 0.8508 acc_train: 0.7286 acc_val: 0.7100 acc_test: 0.7230 time: 0.0363s
# Epoch: 0238 loss_train: 0.8793 acc_train: 0.7214 acc_val: 0.6980 acc_test: 0.7200 time: 0.0327s
# Epoch: 0239 loss_train: 1.0263 acc_train: 0.6929 acc_val: 0.6980 acc_test: 0.7140 time: 0.0331s
# Epoch: 0240 loss_train: 1.0224 acc_train: 0.6643 acc_val: 0.6960 acc_test: 0.7120 time: 0.0357s
# Epoch: 0241 loss_train: 0.8852 acc_train: 0.7286 acc_val: 0.7020 acc_test: 0.7160 time: 0.0351s
# Epoch: 0242 loss_train: 1.0308 acc_train: 0.6500 acc_val: 0.7000 acc_test: 0.7130 time: 0.0349s
# Epoch: 0243 loss_train: 0.9907 acc_train: 0.6571 acc_val: 0.7040 acc_test: 0.7150 time: 0.0334s
# Epoch: 0244 loss_train: 1.0011 acc_train: 0.6357 acc_val: 0.7040 acc_test: 0.7180 time: 0.0333s
# Epoch: 0245 loss_train: 0.9554 acc_train: 0.6500 acc_val: 0.7080 acc_test: 0.7080 time: 0.0331s
# Epoch: 0246 loss_train: 0.9093 acc_train: 0.6714 acc_val: 0.7000 acc_test: 0.7070 time: 0.0357s
# Epoch: 0247 loss_train: 0.8538 acc_train: 0.7214 acc_val: 0.7020 acc_test: 0.7060 time: 0.0380s
# Epoch: 0248 loss_train: 0.8810 acc_train: 0.6929 acc_val: 0.7040 acc_test: 0.7090 time: 0.0336s
# Epoch: 0249 loss_train: 0.9268 acc_train: 0.6429 acc_val: 0.7000 acc_test: 0.7040 time: 0.0333s
# Epoch: 0250 loss_train: 0.9151 acc_train: 0.6643 acc_val: 0.6980 acc_test: 0.7020 time: 0.0358s
# Epoch: 0251 loss_train: 0.8352 acc_train: 0.7571 acc_val: 0.6960 acc_test: 0.7010 time: 0.0366s
# Epoch: 0252 loss_train: 0.8083 acc_train: 0.7143 acc_val: 0.6960 acc_test: 0.7000 time: 0.0332s
# Epoch: 0253 loss_train: 0.9787 acc_train: 0.6786 acc_val: 0.7000 acc_test: 0.6990 time: 0.0332s
# Epoch: 0254 loss_train: 0.9031 acc_train: 0.6786 acc_val: 0.6980 acc_test: 0.7010 time: 0.0356s
# Epoch: 0255 loss_train: 0.9563 acc_train: 0.6714 acc_val: 0.7040 acc_test: 0.7060 time: 0.0389s
# Epoch: 0256 loss_train: 0.8867 acc_train: 0.6929 acc_val: 0.7140 acc_test: 0.7060 time: 0.0333s
# Epoch: 0257 loss_train: 0.8889 acc_train: 0.7286 acc_val: 0.7160 acc_test: 0.7090 time: 0.0332s
# Epoch: 0258 loss_train: 0.9753 acc_train: 0.6643 acc_val: 0.7200 acc_test: 0.7080 time: 0.0334s
# Epoch: 0259 loss_train: 0.9380 acc_train: 0.6857 acc_val: 0.7140 acc_test: 0.7030 time: 0.0368s
# Epoch: 0260 loss_train: 0.8371 acc_train: 0.7286 acc_val: 0.7100 acc_test: 0.7010 time: 0.0381s
# Epoch: 0261 loss_train: 0.9285 acc_train: 0.6857 acc_val: 0.7040 acc_test: 0.6990 time: 0.0338s
# Epoch: 0262 loss_train: 0.9290 acc_train: 0.6714 acc_val: 0.7020 acc_test: 0.6930 time: 0.0320s
# Epoch: 0263 loss_train: 0.8227 acc_train: 0.7643 acc_val: 0.6980 acc_test: 0.6890 time: 0.0336s
# Epoch: 0264 loss_train: 0.8619 acc_train: 0.7214 acc_val: 0.6960 acc_test: 0.6880 time: 0.0332s
# Epoch: 0265 loss_train: 0.9204 acc_train: 0.7000 acc_val: 0.6940 acc_test: 0.6880 time: 0.0376s
# Epoch: 0266 loss_train: 0.9206 acc_train: 0.6786 acc_val: 0.6920 acc_test: 0.6860 time: 0.0336s
# Epoch: 0267 loss_train: 0.8840 acc_train: 0.7143 acc_val: 0.6940 acc_test: 0.6860 time: 0.0318s
# Epoch: 0268 loss_train: 0.9447 acc_train: 0.6429 acc_val: 0.6940 acc_test: 0.6860 time: 0.0328s
# Epoch: 0269 loss_train: 0.8881 acc_train: 0.7071 acc_val: 0.6980 acc_test: 0.6870 time: 0.0330s
# Epoch: 0270 loss_train: 0.7465 acc_train: 0.7643 acc_val: 0.7000 acc_test: 0.6880 time: 0.0358s
# Epoch: 0271 loss_train: 0.9149 acc_train: 0.7071 acc_val: 0.7040 acc_test: 0.6960 time: 0.0372s
# Epoch: 0272 loss_train: 0.8733 acc_train: 0.7071 acc_val: 0.7040 acc_test: 0.7060 time: 0.0332s
# Epoch: 0273 loss_train: 0.8339 acc_train: 0.7071 acc_val: 0.7060 acc_test: 0.7120 time: 0.0335s
# Epoch: 0274 loss_train: 0.7927 acc_train: 0.7286 acc_val: 0.7080 acc_test: 0.7150 time: 0.0330s
# Epoch: 0275 loss_train: 0.7928 acc_train: 0.7214 acc_val: 0.7100 acc_test: 0.7160 time: 0.0332s
# Epoch: 0276 loss_train: 0.8121 acc_train: 0.7143 acc_val: 0.7140 acc_test: 0.7180 time: 0.0369s
# Epoch: 0277 loss_train: 0.8281 acc_train: 0.7000 acc_val: 0.7080 acc_test: 0.7150 time: 0.0368s
# Epoch: 0278 loss_train: 0.8989 acc_train: 0.6929 acc_val: 0.7040 acc_test: 0.7170 time: 0.0330s
# Epoch: 0279 loss_train: 0.7677 acc_train: 0.7143 acc_val: 0.7000 acc_test: 0.7100 time: 0.0318s
# Epoch: 0280 loss_train: 0.8647 acc_train: 0.7429 acc_val: 0.7060 acc_test: 0.7060 time: 0.0335s
# Epoch: 0281 loss_train: 0.9647 acc_train: 0.7214 acc_val: 0.7080 acc_test: 0.7050 time: 0.0331s
# Epoch: 0282 loss_train: 0.7718 acc_train: 0.7357 acc_val: 0.7020 acc_test: 0.7060 time: 0.0357s
# Epoch: 0283 loss_train: 0.8059 acc_train: 0.7286 acc_val: 0.7040 acc_test: 0.7050 time: 0.0371s
# Epoch: 0284 loss_train: 0.7385 acc_train: 0.7571 acc_val: 0.7080 acc_test: 0.7060 time: 0.0329s
# Epoch: 0285 loss_train: 0.8853 acc_train: 0.6929 acc_val: 0.7100 acc_test: 0.7130 time: 0.0330s
# Epoch: 0286 loss_train: 0.7722 acc_train: 0.8071 acc_val: 0.7120 acc_test: 0.7090 time: 0.0331s
# Epoch: 0287 loss_train: 0.8595 acc_train: 0.7286 acc_val: 0.7120 acc_test: 0.7090 time: 0.0403s
# Epoch: 0288 loss_train: 0.8725 acc_train: 0.6857 acc_val: 0.7080 acc_test: 0.7080 time: 0.0338s
# Epoch: 0289 loss_train: 0.7069 acc_train: 0.7571 acc_val: 0.7100 acc_test: 0.7080 time: 0.0355s
# Epoch: 0290 loss_train: 0.8149 acc_train: 0.7714 acc_val: 0.7180 acc_test: 0.7070 time: 0.0378s
# Epoch: 0291 loss_train: 0.7471 acc_train: 0.7571 acc_val: 0.7200 acc_test: 0.7090 time: 0.0400s
# Epoch: 0292 loss_train: 0.8093 acc_train: 0.7071 acc_val: 0.7160 acc_test: 0.7150 time: 0.0348s
# Epoch: 0293 loss_train: 0.8825 acc_train: 0.6929 acc_val: 0.7160 acc_test: 0.7170 time: 0.0347s
# Epoch: 0294 loss_train: 0.7937 acc_train: 0.7643 acc_val: 0.7180 acc_test: 0.7210 time: 0.0346s
# Epoch: 0295 loss_train: 0.8473 acc_train: 0.7214 acc_val: 0.7200 acc_test: 0.7220 time: 0.0338s
# Epoch: 0296 loss_train: 0.8948 acc_train: 0.7429 acc_val: 0.7220 acc_test: 0.7270 time: 0.0353s
# Epoch: 0297 loss_train: 0.7275 acc_train: 0.7429 acc_val: 0.7220 acc_test: 0.7230 time: 0.0378s
# Epoch: 0298 loss_train: 0.6986 acc_train: 0.8071 acc_val: 0.7160 acc_test: 0.7140 time: 0.0388s
# Epoch: 0299 loss_train: 0.7387 acc_train: 0.7786 acc_val: 0.7080 acc_test: 0.7150 time: 0.0352s
# Epoch: 0300 loss_train: 0.8750 acc_train: 0.7143 acc_val: 0.7060 acc_test: 0.7140 time: 0.0350s
# Epoch: 0301 loss_train: 0.7202 acc_train: 0.7929 acc_val: 0.7020 acc_test: 0.7110 time: 0.0383s
# Epoch: 0302 loss_train: 0.8135 acc_train: 0.6929 acc_val: 0.7040 acc_test: 0.7090 time: 0.0329s
# Epoch: 0303 loss_train: 0.8186 acc_train: 0.6786 acc_val: 0.7080 acc_test: 0.7100 time: 0.0376s
# Epoch: 0304 loss_train: 0.7192 acc_train: 0.7571 acc_val: 0.7080 acc_test: 0.7120 time: 0.0363s
# Epoch: 0305 loss_train: 0.6272 acc_train: 0.8429 acc_val: 0.7120 acc_test: 0.7110 time: 0.0370s
# Epoch: 0306 loss_train: 0.7259 acc_train: 0.7786 acc_val: 0.7080 acc_test: 0.7110 time: 0.0347s
# Epoch: 0307 loss_train: 0.8300 acc_train: 0.7500 acc_val: 0.7040 acc_test: 0.7140 time: 0.0347s
# Epoch: 0308 loss_train: 0.8273 acc_train: 0.7357 acc_val: 0.6920 acc_test: 0.7080 time: 0.0346s
# Epoch: 0309 loss_train: 0.7308 acc_train: 0.7571 acc_val: 0.6880 acc_test: 0.6980 time: 0.0349s
# Epoch: 0310 loss_train: 0.6865 acc_train: 0.7786 acc_val: 0.6920 acc_test: 0.6930 time: 0.0350s
# Epoch: 0311 loss_train: 0.7029 acc_train: 0.7500 acc_val: 0.6920 acc_test: 0.6900 time: 0.0371s
# Epoch: 0312 loss_train: 0.8051 acc_train: 0.7429 acc_val: 0.6940 acc_test: 0.6890 time: 0.0334s
# Epoch: 0313 loss_train: 0.7555 acc_train: 0.7143 acc_val: 0.6880 acc_test: 0.6860 time: 0.0342s
# Epoch: 0314 loss_train: 0.7300 acc_train: 0.7786 acc_val: 0.6900 acc_test: 0.6880 time: 0.0372s
# Epoch: 0315 loss_train: 0.6933 acc_train: 0.7429 acc_val: 0.6920 acc_test: 0.6900 time: 0.0381s
# Epoch: 0316 loss_train: 0.6953 acc_train: 0.7500 acc_val: 0.6920 acc_test: 0.6970 time: 0.0346s
# Epoch: 0317 loss_train: 0.6849 acc_train: 0.8143 acc_val: 0.6980 acc_test: 0.7050 time: 0.0348s
# Epoch: 0318 loss_train: 0.6127 acc_train: 0.8071 acc_val: 0.6980 acc_test: 0.7090 time: 0.0346s
# Epoch: 0319 loss_train: 0.7320 acc_train: 0.7500 acc_val: 0.7020 acc_test: 0.7130 time: 0.0347s
# Epoch: 0320 loss_train: 0.6391 acc_train: 0.8286 acc_val: 0.6980 acc_test: 0.7170 time: 0.0349s
# Epoch: 0321 loss_train: 0.6908 acc_train: 0.7071 acc_val: 0.6940 acc_test: 0.7170 time: 0.0346s
# Epoch: 0322 loss_train: 0.6067 acc_train: 0.7643 acc_val: 0.7000 acc_test: 0.7240 time: 0.0338s
# Epoch: 0323 loss_train: 0.5691 acc_train: 0.8143 acc_val: 0.7060 acc_test: 0.7210 time: 0.0345s
# Epoch: 0324 loss_train: 0.6708 acc_train: 0.8071 acc_val: 0.7000 acc_test: 0.7210 time: 0.0373s
# Epoch: 0325 loss_train: 0.7306 acc_train: 0.7357 acc_val: 0.7060 acc_test: 0.7230 time: 0.0305s
# Epoch: 0326 loss_train: 0.6034 acc_train: 0.8000 acc_val: 0.7020 acc_test: 0.7200 time: 0.0344s
# Epoch: 0327 loss_train: 0.6176 acc_train: 0.8000 acc_val: 0.6980 acc_test: 0.7200 time: 0.0320s
# Epoch: 0328 loss_train: 0.6692 acc_train: 0.7500 acc_val: 0.6940 acc_test: 0.7180 time: 0.0330s
# Epoch: 0329 loss_train: 0.8004 acc_train: 0.7000 acc_val: 0.6960 acc_test: 0.7140 time: 0.0335s
# Epoch: 0330 loss_train: 0.7027 acc_train: 0.7357 acc_val: 0.6940 acc_test: 0.7080 time: 0.0337s
# Epoch: 0331 loss_train: 0.6553 acc_train: 0.7643 acc_val: 0.6860 acc_test: 0.7060 time: 0.0384s
# Epoch: 0332 loss_train: 0.7130 acc_train: 0.7571 acc_val: 0.6860 acc_test: 0.7020 time: 0.0344s
# Epoch: 0333 loss_train: 0.6073 acc_train: 0.8500 acc_val: 0.6820 acc_test: 0.6940 time: 0.0320s
# Epoch: 0334 loss_train: 1.0062 acc_train: 0.7643 acc_val: 0.6780 acc_test: 0.6850 time: 0.0336s
# Epoch: 0335 loss_train: 0.8079 acc_train: 0.7000 acc_val: 0.6740 acc_test: 0.6740 time: 0.0336s
# Epoch: 0336 loss_train: 0.5319 acc_train: 0.8429 acc_val: 0.6680 acc_test: 0.6730 time: 0.0332s
# Epoch: 0337 loss_train: 0.6367 acc_train: 0.8286 acc_val: 0.6680 acc_test: 0.6710 time: 0.0389s
# Epoch: 0338 loss_train: 0.7373 acc_train: 0.7286 acc_val: 0.6680 acc_test: 0.6670 time: 0.0320s
# Epoch: 0339 loss_train: 0.6396 acc_train: 0.8143 acc_val: 0.6680 acc_test: 0.6680 time: 0.0330s
# Epoch: 0340 loss_train: 0.6419 acc_train: 0.7929 acc_val: 0.6740 acc_test: 0.6730 time: 0.0330s
# Epoch: 0341 loss_train: 0.7094 acc_train: 0.8000 acc_val: 0.6780 acc_test: 0.6750 time: 0.0336s
# Epoch: 0342 loss_train: 0.6310 acc_train: 0.7857 acc_val: 0.6780 acc_test: 0.6760 time: 0.0357s
# Epoch: 0343 loss_train: 0.7135 acc_train: 0.7714 acc_val: 0.6780 acc_test: 0.6760 time: 0.0373s
# Epoch: 0344 loss_train: 0.6311 acc_train: 0.7857 acc_val: 0.6820 acc_test: 0.6830 time: 0.0319s
# Epoch: 0345 loss_train: 0.6120 acc_train: 0.8571 acc_val: 0.6980 acc_test: 0.6950 time: 0.0336s
# Epoch: 0346 loss_train: 0.6806 acc_train: 0.7429 acc_val: 0.7040 acc_test: 0.6940 time: 0.0330s
# Epoch: 0347 loss_train: 0.7971 acc_train: 0.7357 acc_val: 0.6960 acc_test: 0.7020 time: 0.0356s
# Epoch: 0348 loss_train: 0.5262 acc_train: 0.8071 acc_val: 0.7000 acc_test: 0.7040 time: 0.0361s
# Epoch: 0349 loss_train: 0.6322 acc_train: 0.7786 acc_val: 0.7020 acc_test: 0.7030 time: 0.0339s
# Epoch: 0350 loss_train: 0.6374 acc_train: 0.7714 acc_val: 0.6960 acc_test: 0.7060 time: 0.0330s
# Epoch: 0351 loss_train: 0.7017 acc_train: 0.7500 acc_val: 0.6920 acc_test: 0.6980 time: 0.0335s
# Epoch: 0352 loss_train: 0.5635 acc_train: 0.8357 acc_val: 0.6840 acc_test: 0.6880 time: 0.0331s
# Epoch: 0353 loss_train: 0.7048 acc_train: 0.7786 acc_val: 0.6680 acc_test: 0.6700 time: 0.0358s
# Epoch: 0354 loss_train: 0.7220 acc_train: 0.7500 acc_val: 0.6580 acc_test: 0.6620 time: 0.0355s
# Epoch: 0355 loss_train: 0.6565 acc_train: 0.8000 acc_val: 0.6480 acc_test: 0.6460 time: 0.0339s
# Epoch: 0356 loss_train: 0.7618 acc_train: 0.8429 acc_val: 0.6420 acc_test: 0.6370 time: 0.0334s
# Epoch: 0357 loss_train: 0.8436 acc_train: 0.7500 acc_val: 0.6340 acc_test: 0.6340 time: 0.0332s
# Epoch: 0358 loss_train: 0.6475 acc_train: 0.8000 acc_val: 0.6320 acc_test: 0.6290 time: 0.0357s
# Epoch: 0359 loss_train: 0.7772 acc_train: 0.7071 acc_val: 0.6280 acc_test: 0.6280 time: 0.0388s
# Epoch: 0360 loss_train: 0.6177 acc_train: 0.8071 acc_val: 0.6360 acc_test: 0.6350 time: 0.0318s
# Epoch: 0361 loss_train: 0.6609 acc_train: 0.7857 acc_val: 0.6380 acc_test: 0.6390 time: 0.0343s
# Epoch: 0362 loss_train: 0.6495 acc_train: 0.8071 acc_val: 0.6560 acc_test: 0.6500 time: 0.0337s
# Epoch: 0363 loss_train: 0.6962 acc_train: 0.8071 acc_val: 0.6640 acc_test: 0.6650 time: 0.0331s
# Epoch: 0364 loss_train: 1.9858 acc_train: 0.7571 acc_val: 0.6660 acc_test: 0.6720 time: 0.0350s
# Epoch: 0365 loss_train: 0.8241 acc_train: 0.7214 acc_val: 0.6680 acc_test: 0.6740 time: 0.0364s
# Epoch: 0366 loss_train: 0.7229 acc_train: 0.7357 acc_val: 0.6740 acc_test: 0.6760 time: 0.0318s
# Epoch: 0367 loss_train: 0.6785 acc_train: 0.8000 acc_val: 0.6780 acc_test: 0.6780 time: 0.0328s
# Epoch: 0368 loss_train: 0.6773 acc_train: 0.7929 acc_val: 0.6760 acc_test: 0.6820 time: 0.0337s
# Epoch: 0369 loss_train: 0.7239 acc_train: 0.7500 acc_val: 0.6840 acc_test: 0.6820 time: 0.0358s
# Epoch: 0370 loss_train: 0.6865 acc_train: 0.8000 acc_val: 0.6800 acc_test: 0.6840 time: 0.0366s
# Epoch: 0371 loss_train: 0.6749 acc_train: 0.7500 acc_val: 0.6740 acc_test: 0.6790 time: 0.0319s
# Epoch: 0372 loss_train: 0.6211 acc_train: 0.8143 acc_val: 0.6680 acc_test: 0.6720 time: 0.0331s
# Epoch: 0373 loss_train: 0.7481 acc_train: 0.7857 acc_val: 0.6680 acc_test: 0.6700 time: 0.0341s
# Epoch: 0374 loss_train: 0.7923 acc_train: 0.8000 acc_val: 0.6640 acc_test: 0.6690 time: 0.0332s
# Epoch: 0375 loss_train: 0.8428 acc_train: 0.7500 acc_val: 0.6620 acc_test: 0.6550 time: 0.0361s
# Epoch: 0376 loss_train: 1.0135 acc_train: 0.7786 acc_val: 0.6520 acc_test: 0.6440 time: 0.0360s
# Epoch: 0377 loss_train: 0.6003 acc_train: 0.8286 acc_val: 0.6360 acc_test: 0.6320 time: 0.0335s
# Epoch: 0378 loss_train: 0.7936 acc_train: 0.7143 acc_val: 0.6300 acc_test: 0.6260 time: 0.0332s
# Epoch: 0379 loss_train: 0.7606 acc_train: 0.7143 acc_val: 0.6300 acc_test: 0.6230 time: 0.0343s
# Epoch: 0380 loss_train: 0.7729 acc_train: 0.7500 acc_val: 0.6320 acc_test: 0.6240 time: 0.0330s
# Epoch: 0381 loss_train: 0.6939 acc_train: 0.7929 acc_val: 0.6280 acc_test: 0.6260 time: 0.0357s
# Epoch: 0382 loss_train: 0.6581 acc_train: 0.8286 acc_val: 0.6240 acc_test: 0.6290 time: 0.0364s
# Epoch: 0383 loss_train: 0.7471 acc_train: 0.7857 acc_val: 0.6340 acc_test: 0.6310 time: 0.0338s
# Epoch: 0384 loss_train: 0.7147 acc_train: 0.7857 acc_val: 0.6440 acc_test: 0.6430 time: 0.0332s
# Epoch: 0385 loss_train: 0.6014 acc_train: 0.7929 acc_val: 0.6580 acc_test: 0.6530 time: 0.0345s
# Epoch: 0386 loss_train: 0.7414 acc_train: 0.7214 acc_val: 0.6640 acc_test: 0.6570 time: 0.0332s
# Epoch: 0387 loss_train: 0.6186 acc_train: 0.7786 acc_val: 0.6620 acc_test: 0.6680 time: 0.0330s
# Epoch: 0388 loss_train: 0.7360 acc_train: 0.7286 acc_val: 0.6620 acc_test: 0.6690 time: 0.0334s
# Epoch: 0389 loss_train: 0.6334 acc_train: 0.7571 acc_val: 0.6700 acc_test: 0.6710 time: 0.0357s
# Epoch: 0390 loss_train: 0.8672 acc_train: 0.7643 acc_val: 0.6640 acc_test: 0.6710 time: 0.0364s
# Epoch: 0391 loss_train: 0.6253 acc_train: 0.8071 acc_val: 0.6640 acc_test: 0.6710 time: 0.0328s
# Epoch: 0392 loss_train: 0.6745 acc_train: 0.7357 acc_val: 0.6640 acc_test: 0.6710 time: 0.0337s
# Epoch: 0393 loss_train: 0.7034 acc_train: 0.7500 acc_val: 0.6640 acc_test: 0.6720 time: 0.0352s
# Epoch: 0394 loss_train: 0.7953 acc_train: 0.7929 acc_val: 0.6600 acc_test: 0.6640 time: 0.0331s
# Epoch: 0395 loss_train: 0.7091 acc_train: 0.7857 acc_val: 0.6560 acc_test: 0.6610 time: 0.0333s
# Epoch: 0396 loss_train: 0.6069 acc_train: 0.8286 acc_val: 0.6520 acc_test: 0.6580 time: 0.0355s
# Epoch: 0397 loss_train: 0.7465 acc_train: 0.7714 acc_val: 0.6540 acc_test: 0.6580 time: 0.0367s
# Epoch: 0398 loss_train: 0.6720 acc_train: 0.7571 acc_val: 0.6500 acc_test: 0.6560 time: 0.0322s
# Epoch: 0399 loss_train: 0.6124 acc_train: 0.8214 acc_val: 0.6480 acc_test: 0.6530 time: 0.0330s
# Epoch: 0400 loss_train: 0.6444 acc_train: 0.7714 acc_val: 0.6480 acc_test: 0.6540 time: 0.0330s
# Optimization Finished!
# Total time elapsed: 14.5415s
# 0.806 0.837
# 0.802 0.8140000000000001
# 0.8 0.8150000000000001
# 0.798 0.8200000000000001
# 0.796 0.847
# 0.794 0.837
# 0.792 0.8200000000000001
# 0.79 0.8170000000000001
# 0.788 0.837
# 0.786 0.8170000000000001
